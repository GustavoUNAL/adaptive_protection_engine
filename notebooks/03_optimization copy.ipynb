# %% [markdown]
# ## Algoritmo de automatización

# %%
import json
import numpy as np
import logging
import os
import math
import copy
import random
import string
from datetime import datetime, timezone
from typing import Dict, List, Any, Optional, Tuple, Set

# --- Configuration ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# --- File Paths ---
# !!! PLEASE UPDATE THESE PATHS TO YOUR ACTUAL FILE LOCATIONS !!!
RELAY_PAIRS_PATH = "/Users/gustavo/Documents/Projects/TESIS_UNAL/ADAPTIVE_ALGORITHM/data/processed/independent_relay_pairs_automation.json"
OPTIMIZED_SETTINGS_OUTPUT_PATH = "/Users/gustavo/Documents/Projects/TESIS_UNAL/ADAPTIVE_ALGORITHM/data/raw/optimized_relay_values.json" 

# --- Constants ---
K = 0.14
N = 0.02
CTI = 0.2
# Optimization Bounds and Parameters
MIN_TDS = 0.05 # Lower practical limit for TDS
MAX_TDS = 1
MIN_PICKUP = 0.05
# Stricter pickup limit relative to Ishc, inspired by snippet
MAX_PICKUP_FACTOR = 0.7
# MAX_TIME still needed for constraint violations, but not for calculation errors
MAX_TIME = 20.0
MAX_ITERATIONS = 250 # More iterations might be needed
# Convergence Targets
TARGET_TMT = -0.005 # Target for *total* miscoordination time (can stay negative)
# ***MODIFIED: New threshold for individual Margin Time (MT)***
MIN_ALLOWED_INDIVIDUAL_MT = -0.009 # Convergence threshold for the most negative individual MT
CONVERGENCE_THRESHOLD_TMT = 0.005 # Smaller margin for TMT (still used for stagnation check)
# Objective Function Weights
W_TIME = 0.1 # Further decrease weight of total time
W_MT = 15.0 # Increase weight for miscoordination penalty
W_PICKUP_DIFF = 0.0
# Adjustment Step Sizes & Factors (Inspired by Snippet)
AGGRESSIVE_MT_THRESHOLD = -CTI * 0.75 # Threshold to trigger aggressive adjustments
# Aggressive Steps
AGGRESSIVE_TDS_BACKUP_FACTOR = 1.15 # Increase backup TDS more
AGGRESSIVE_TDS_MAIN_FACTOR = 0.90  # Decrease main TDS more
AGGRESSIVE_PICKUP_BACKUP_FACTOR = 1.05 # Increase backup pickup if TDS maxed out
# Normal Steps (additive for TDS, small mult for pickup)
NORMAL_TDS_BACKUP_ADD = 0.02
NORMAL_TDS_MAIN_SUB = 0.01
NORMAL_PICKUP_BACKUP_FACTOR = 1.01
NORMAL_PICKUP_MAIN_FACTOR = 0.99


# --- Helper Functions ---
def load_json_file(file_path: str) -> Optional[Any]:
    try:
        with open(file_path, 'r') as file: data = json.load(file)
        logger.info(f"Archivo cargado: {file_path}"); return data
    except FileNotFoundError: logger.error(f"No encontrado: {file_path}"); return None
    except json.JSONDecodeError as e: logger.error(f"JSON inválido: {file_path}: {e}"); return None
    except Exception as e: logger.error(f"Error carga {file_path}: {e}"); return None

# MODIFIED: Returns Optional[float] - None indicates calculation error
def calculate_operation_time(I_shc: float, I_pi: float, TDS: float) -> Optional[float]:
    """Calculates relay operation time. Returns None if calculation is impossible."""
    # Basic Input Validation / Conditions for non-calculation
    if I_pi <= 0 or I_shc <= 0 or TDS < MIN_TDS or TDS > MAX_TDS:
        # logger.debug(f"Calc Error: Invalid input I_shc={I_shc}, I_pi={I_pi}, TDS={TDS}")
        return None # Return None for impossible basic inputs

    # Pickup Constraint Check (Violation leads to MAX_TIME, not None)
    # Allow pickup up to Ishc*factor. If it exceeds, it's a constraint violation.
    if I_pi > I_shc * MAX_PICKUP_FACTOR:
        # logger.debug(f"Calc Constraint Violation: I_pi={I_pi} > I_shc*factor={I_shc * MAX_PICKUP_FACTOR}")
        return MAX_TIME # Return MAX_TIME for pickup constraint violation

    M = I_shc / I_pi
    # Check for M close to or below 1 (prevents division by zero/negative log)
    # If pickup is *valid* but M <= 1, it means the relay shouldn't operate -> MAX_TIME
    if M <= 1.0:
        # logger.debug(f"Non-operation: M={M} <= 1.0 (I_shc={I_shc}, I_pi={I_pi})")
        return MAX_TIME # Return MAX_TIME if M indicates non-operation

    try:
        denominator = M**N - 1
        # Check for near-zero denominator (should be less likely now M > 1 is enforced)
        if abs(denominator) < 1e-9:
            # logger.debug(f"Calc Error: Denominator near zero ({denominator})")
            return None # Return None for division by zero (potential numerical instability)

        time = TDS * (K / denominator)

        # Check for non-finite or non-positive results
        if not np.isfinite(time) or time <= 0:
             # logger.debug(f"Calc Error: Result non-finite or non-positive ({time})")
             return None # Return None for invalid results

        return min(time, MAX_TIME) # Return calculated time, capped by MAX_TIME

    except (OverflowError, ValueError) as e:
        # logger.debug(f"Calc Error: Math exception M={M}, N={N} -> {e}")
        return None # Return None on math errors
    except Exception as e:
        logger.error(f"Excepción inesperada en calc_op_time (I_shc={I_shc}, I_pi={I_pi}, TDS={TDS}): {e}")
        return None # Return None for any other unexpected error

def group_data_by_scenario(relay_pairs_data: List[Dict]) -> Dict[str, Dict[str, Any]]:
    scenario_map: Dict[str, Dict[str, Any]] = {}
    processed_pairs_count = 0
    skipped_pairs_count = 0
    for i, pair_entry in enumerate(relay_pairs_data):
        scenario_id = pair_entry.get("scenario_id")
        main_relay_info = pair_entry.get('main_relay'); backup_relay_info = pair_entry.get('backup_relay')
        if not scenario_id or not isinstance(main_relay_info, dict) or not isinstance(backup_relay_info, dict):
            # logger.warning(f"Omitiendo entrada de par {i+1}: Falta scenario_id o info de relé inválida.")
            skipped_pairs_count+=1; continue
        if scenario_id not in scenario_map: scenario_map[scenario_id] = {"pairs_info": [], "initial_settings": {}, "relays": set()}
        main_relay = main_relay_info.get('relay'); backup_relay = backup_relay_info.get('relay')
        I_shc_main = main_relay_info.get('Ishc'); I_shc_backup = backup_relay_info.get('Ishc')
        # Ensure Ishc are positive numbers for calculations
        if not (main_relay and backup_relay and
                isinstance(I_shc_main, (int, float)) and I_shc_main > 0 and
                isinstance(I_shc_backup, (int, float)) and I_shc_backup > 0):
            # logger.warning(f"Omitiendo par {main_relay}/{backup_relay} en {scenario_id}: Falta nombre de relé o Ishc inválido/no positivo (Main: {I_shc_main}, Backup: {I_shc_backup}).")
            skipped_pairs_count+=1; continue

        processed_pairs_count += 1
        scenario_map[scenario_id]['relays'].add(main_relay); scenario_map[scenario_id]['relays'].add(backup_relay)
        initial_settings_scenario = scenario_map[scenario_id]['initial_settings']
        for r_name, r_info in [(main_relay, main_relay_info), (backup_relay, backup_relay_info)]:
            if r_name not in initial_settings_scenario:
                tds = r_info.get('TDS'); pickup = r_info.get('pick_up') # Key is 'pick_up' in input
                if isinstance(tds, (int, float)) and isinstance(pickup, (int, float)):
                    initial_settings_scenario[r_name] = {
                        'TDS_initial': float(tds),
                        'pickup_initial': float(pickup)
                         }
                # else:
                    # logger.warning(f"({scenario_id}) Config inicial TDS/pickup no encontrada o inválida para '{r_name}' en la entrada de par. Se usarán valores por defecto si es necesario más adelante.")
        scenario_map[scenario_id]['pairs_info'].append({"main_relay": main_relay, "backup_relay": backup_relay, "I_shc_main": float(I_shc_main), "I_shc_backup": float(I_shc_backup)})

    logger.info(f"Datos agrupados por escenario. Pares procesados: {processed_pairs_count}, Pares omitidos: {skipped_pairs_count}")
    return scenario_map


# --- Scenario-Specific Optimization Function (MODIFIED for None handling and new convergence) ---
def run_scenario_optimization(
    scenario_id: str,
    pairs_info: List[Dict],
    initial_settings: Dict[str, Dict[str, float]], # Contains TDS_initial, pickup_initial
    relays_in_scenario: Set[str]
) -> Dict[str, Dict[str, float]]:
    """Performs iterative optimization, handles calculation errors (None), excludes errors from TMT, and uses the new individual MT convergence threshold."""

    logger.info(f"--- Iniciando optimización para {scenario_id} ---")
    if not pairs_info: logger.warning(f"({scenario_id}) No hay pares válidos."); return {}

    # 1. Initialize settings - Use initial Pickup, MIN TDS
    relay_settings = {}
    default_pickup = MIN_PICKUP * 1.5 # Start slightly above min

    for relay in relays_in_scenario:
         if relay in initial_settings:
             relay_settings[relay] = {
                 "TDS": MIN_TDS,
                 "pickup": max(MIN_PICKUP, initial_settings[relay]['pickup_initial'])
             }
         else:
             logger.warning(f"({scenario_id}) Config inicial (pickup) no encontrada para '{relay}'. Usando defecto.")
             relay_settings[relay] = {"TDS": MIN_TDS, "pickup": default_pickup}

    # --- Optimization Loop ---
    last_tmt = float('inf')
    no_improvement_streak = 0

    for iteration in range(MAX_ITERATIONS):
        total_main_time = 0.0; tmt = 0.0; miscoordination_penalty = 0.0
        current_pair_results = []; max_neg_mt = 0 # Initialize to 0 (least negative possible)
        error_pairs_count = 0 # Count pairs with calculation errors

        # Calculate performance
        for pair in pairs_info:
            main_relay = pair["main_relay"]; backup_relay = pair["backup_relay"]
            I_shc_main = pair["I_shc_main"]; I_shc_backup = pair["I_shc_backup"]
            if main_relay not in relay_settings or backup_relay not in relay_settings: continue # Should not happen with grouping logic

            tds_main = relay_settings[main_relay]["TDS"]
            pickup_main = relay_settings[main_relay]["pickup"]
            tds_backup = relay_settings[backup_relay]["TDS"]
            pickup_backup = relay_settings[backup_relay]["pickup"]

            # Apply pickup bounds BEFORE calculating time
            # MAX_PICKUP_FACTOR constraint is checked *inside* calculate_operation_time
            pickup_main_bounded = max(MIN_PICKUP, pickup_main)
            pickup_backup_bounded = max(MIN_PICKUP, pickup_backup)

            # Calculate times - MODIFIED: handle None return
            main_time = calculate_operation_time(I_shc_main, pickup_main_bounded, tds_main)
            backup_time = calculate_operation_time(I_shc_backup, pickup_backup_bounded, tds_backup)

            delta_t: Optional[float] = None
            mt: Optional[float] = None

            # Check for calculation errors (None) first
            if main_time is None or backup_time is None:
                delta_t = None
                mt = None
                error_pairs_count += 1
                # logger.debug(f"({scenario_id}) Iter {iteration+1}: Error calc pair {main_relay}({main_time})/{backup_relay}({backup_time})")
            # Check for MAX_TIME (constraint violation or non-operation) next
            elif main_time >= MAX_TIME or backup_time >= MAX_TIME:
                 # If one is MAX_TIME and the other isn't, coordination is definitely violated.
                 # If both are MAX_TIME, they don't coordinate, but it's not a typical miscoordination.
                 # Assign a large penalty value to mt to indicate a severe issue, but not infinity.
                 # Avoid using MAX_TIME directly for mt calculation if possible to distinguish from calc error
                 delta_t = backup_time - main_time if main_time < MAX_TIME and backup_time < MAX_TIME else MAX_TIME
                 # If delta_t is MAX_TIME (or either time was MAX_TIME), assign a large penalty to mt
                 mt = MAX_TIME * 2 # Assign a large penalty if times are MAX_TIME
                 # logger.debug(f"({scenario_id}) Iter {iteration+1}: MAX_TIME detected for {main_relay}({main_time})/{backup_relay}({backup_time}) -> mt={mt}")
            # Otherwise, calculate normally
            else:
                 delta_t = backup_time - main_time
                 mt = delta_t - CTI

            current_pair_results.append({
                "main_time": main_time, "backup_time": backup_time, # Can be None, float, or MAX_TIME
                "delta_t": delta_t, "mt": mt, # Can be None, float, or large penalty value
                "main_relay": main_relay, "backup_relay": backup_relay,
                "I_shc_main": I_shc_main, "I_shc_backup": I_shc_backup
            })

            # --- Accumulate performance metrics - MODIFIED: Skip None values for TMT/Penalty ---
            # Add main time only if valid and finite
            if main_time is not None and main_time < MAX_TIME:
                total_main_time += main_time

            # Add to TMT, penalty, and track max_neg_mt ONLY if mt is a valid negative number
            # Exclude the large penalty values assigned for MAX_TIME cases from normal TMT/max_neg_mt
            if mt is not None and mt < 0 and mt < MAX_TIME: # Check mt is negative AND not the large penalty
                tmt += mt
                miscoordination_penalty += mt**2
                max_neg_mt = min(max_neg_mt, mt) # Update the most negative MT found so far
            # --- End Accumulation Modification ---

        # Objective function calculation remains the same structure
        of = W_MT * miscoordination_penalty + W_TIME * total_main_time

        if (iteration + 1) % 25 == 0 or iteration == 0 or tmt > TARGET_TMT*1.1 :
             logger.info(f"({scenario_id}) Iter {iteration+1}/{MAX_ITERATIONS}: OF={of:.4f}, TMT={tmt:.4f}, MaxNegMT={max_neg_mt:.4f}, Errors={error_pairs_count}")

        # --- Check Convergence (MODIFIED: using MIN_ALLOWED_INDIVIDUAL_MT) ---
        # Converge if the total miscoordination is below target AND the worst individual miscoordination is above the minimum allowed limit
        if tmt >= TARGET_TMT and max_neg_mt >= MIN_ALLOWED_INDIVIDUAL_MT:
             logger.info(f"({scenario_id}) Convergencia alcanzada (TMT={tmt:.4f} >= {TARGET_TMT}, MaxNegMT={max_neg_mt:.4f} >= {MIN_ALLOWED_INDIVIDUAL_MT}).")
             break
        # --- End Convergence Check Modification ---

        # --- AJUSTE V3 (MODIFIED: Skip pairs with mt=None or mt indicating MAX_TIME penalty) ---
        adjustments_made = False
        next_relay_settings = copy.deepcopy(relay_settings)

        for pair_res in current_pair_results:
            # --- ADDED: Skip adjustment if mt could not be calculated or indicates MAX_TIME penalty ---
            if pair_res["mt"] is None or pair_res["mt"] >= MAX_TIME :
                continue
            # --- End Skip ---

            # Adjust only miscoordinated pairs (mt < 0 AND mt is not the large penalty value)
            if pair_res["mt"] < 0:
                main_relay = pair_res["main_relay"]; backup_relay = pair_res["backup_relay"]
                I_shc_main = pair_res["I_shc_main"]; I_shc_backup = pair_res["I_shc_backup"]
                mt_val = pair_res["mt"] # We know mt_val is a valid negative float here

                tds_main_curr = next_relay_settings[main_relay]["TDS"]
                tds_backup_curr = next_relay_settings[backup_relay]["TDS"]
                pickup_main_curr = next_relay_settings[main_relay]["pickup"]
                pickup_backup_curr = next_relay_settings[backup_relay]["pickup"]

                new_tds_backup = tds_backup_curr
                new_pickup_backup = pickup_backup_curr
                new_tds_main = tds_main_curr
                new_pickup_main = pickup_main_curr

                # Apply adjustments based on severity
                if mt_val < AGGRESSIVE_MT_THRESHOLD:
                    # Aggressive adjustment
                    # logger.debug(f"({scenario_id}) Iter {iteration+1}: Ajuste Agresivo para {main_relay}/{backup_relay} (mt={mt_val:.4f})")
                    new_tds_backup = min(MAX_TDS, tds_backup_curr * AGGRESSIVE_TDS_BACKUP_FACTOR)
                    # Only adjust pickup if TDS hits max and miscoordination is still severe
                    if abs(new_tds_backup - MAX_TDS) < 1e-6:
                         # Ensure pickup adjustment respects the MAX_PICKUP_FACTOR limit relative to *its* Ishc
                         max_allowed_pickup_backup = I_shc_backup * MAX_PICKUP_FACTOR
                         new_pickup_backup = min(max_allowed_pickup_backup, max(MIN_PICKUP, pickup_backup_curr * AGGRESSIVE_PICKUP_BACKUP_FACTOR))

                    new_tds_main = max(MIN_TDS, tds_main_curr * AGGRESSIVE_TDS_MAIN_FACTOR)
                    # Aggressively decrease main pickup only if main TDS hits min? (Optional refinement)
                    # if abs(new_tds_main - MIN_TDS) < 1e-6:
                    #    max_allowed_pickup_main = I_shc_main * MAX_PICKUP_FACTOR
                    #    new_pickup_main = min(max_allowed_pickup_main, max(MIN_PICKUP, pickup_main_curr * 0.98)) # Example factor

                else:
                    # Normal adjustment
                    # logger.debug(f"({scenario_id}) Iter {iteration+1}: Ajuste Normal para {main_relay}/{backup_relay} (mt={mt_val:.4f})")
                    new_tds_backup = min(MAX_TDS, max(MIN_TDS, tds_backup_curr + NORMAL_TDS_BACKUP_ADD))
                    new_tds_main = min(MAX_TDS, max(MIN_TDS, tds_main_curr - NORMAL_TDS_MAIN_SUB))
                    # Subtle pickup adjustments (less critical now with MAX_PICKUP_FACTOR check in calc_time)
                    # max_allowed_pickup_backup = I_shc_backup * MAX_PICKUP_FACTOR
                    # new_pickup_backup = min(max_allowed_pickup_backup, max(MIN_PICKUP, pickup_backup_curr * NORMAL_PICKUP_BACKUP_FACTOR))
                    # max_allowed_pickup_main = I_shc_main * MAX_PICKUP_FACTOR
                    # new_pickup_main = min(max_allowed_pickup_main, max(MIN_PICKUP, pickup_main_curr * NORMAL_PICKUP_MAIN_FACTOR))


                # Update the temporary settings dict, ensuring bounds are respected immediately
                next_relay_settings[backup_relay]["TDS"] = min(MAX_TDS, max(MIN_TDS, new_tds_backup))
                next_relay_settings[main_relay]["TDS"] = min(MAX_TDS, max(MIN_TDS, new_tds_main))
                # Apply pickup bounds during adjustment application
                max_pickup_b = I_shc_backup * MAX_PICKUP_FACTOR
                max_pickup_m = I_shc_main * MAX_PICKUP_FACTOR
                next_relay_settings[backup_relay]["pickup"] = min(max_pickup_b, max(MIN_PICKUP, new_pickup_backup))
                next_relay_settings[main_relay]["pickup"] = min(max_pickup_m, max(MIN_PICKUP, new_pickup_main))


                adjustments_made = True
        # --- End Adjustment Modification ---

        if adjustments_made:
            relay_settings = next_relay_settings # Apply the adjusted settings for the next iteration
        elif iteration > 15: # Stop if no adjustments needed after initial phase
             logger.info(f"({scenario_id}) No se realizaron ajustes en iteración {iteration + 1}. Deteniendo.")
             break

        # Check for stagnation (based on TMT from valid pairs)
        # Use the original CONVERGENCE_THRESHOLD_TMT for stagnation check magnitude
        if abs(tmt - last_tmt) < CONVERGENCE_THRESHOLD_TMT: # Check if TMT improvement is negligible
            no_improvement_streak += 1
        else:
            no_improvement_streak = 0
        last_tmt = tmt

        if no_improvement_streak >= 25:
            logger.warning(f"({scenario_id}) TMT no mejora significativamente ({no_improvement_streak} iteraciones). Deteniendo.")
            break

    else: # Executes if loop finishes without break (max iterations reached)
        logger.warning(f"({scenario_id}) La optimización no convergió (o no mejoró) después de {MAX_ITERATIONS} iteraciones.")
        # Log final state if max iterations reached
        logger.warning(f"({scenario_id}) Estado final: TMT={tmt:.4f}, MaxNegMT={max_neg_mt:.4f}, Errors={error_pairs_count}")


    # Format final results
    formatted_settings = {}
    relays_max_ishc = {} # Cache max Ishc per relay for final bounding
    for relay in relays_in_scenario:
        max_ishc = 0
        for p in pairs_info:
             if p['main_relay'] == relay: max_ishc = max(max_ishc, p.get('I_shc_main', 0))
             if p['backup_relay'] == relay: max_ishc = max(max_ishc, p.get('I_shc_backup', 0))
        # Ensure there's a sensible Ishc even if a relay only appears with Ishc=0 somehow (use default pickup relation)
        relays_max_ishc[relay] = max_ishc if max_ishc > 0 else (default_pickup / MIN_PICKUP)

    for relay, settings in relay_settings.items():
        final_pickup = settings['pickup']
        max_ishc_relay = relays_max_ishc.get(relay, default_pickup / MIN_PICKUP) # Fallback Ishc

        # Apply final bounds using the max Ishc seen by this relay in this scenario
        # This ensures the final pickup setting is valid w.r.t the highest fault current it needs to handle
        final_pickup_bounded = min(max_ishc_relay * MAX_PICKUP_FACTOR, max(MIN_PICKUP, final_pickup))
        final_tds_bounded = min(MAX_TDS, max(MIN_TDS, settings['TDS']))

        formatted_settings[relay] = {
            "TDS": float(f"{final_tds_bounded:.5f}"),
            "pickup": float(f"{final_pickup_bounded:.5f}")
        }
    logger.info(f"--- Optimización finalizada para {scenario_id} ---")
    return formatted_settings


# --- Script Execution ---
if __name__ == "__main__":
    logger.info("--- Iniciando Script de Optimización de Ajustes de Relés (v4 - MT Threshold -0.009) ---")
    # !!! ENSURE PATHS ARE CORRECT !!!
    if not os.path.exists(RELAY_PAIRS_PATH):
         logger.error(f"¡Error Crítico! No se encontró el archivo de entrada: {RELAY_PAIRS_PATH}")
         raise SystemExit("Archivo de pares de relés no encontrado.")

    relay_pairs_data = load_json_file(RELAY_PAIRS_PATH)
    if relay_pairs_data is None: raise SystemExit("Error crítico al cargar archivo de pares.")

    scenario_data_map = group_data_by_scenario(relay_pairs_data)
    if not scenario_data_map: raise SystemExit("Error crítico al procesar datos de entrada. No se encontraron escenarios o pares válidos.")

    all_optimized_settings = {}
    successful_scenarios = 0
    failed_scenarios = 0
    for scenario_id, scenario_data in scenario_data_map.items():
        if not scenario_data.get('relays') or not scenario_data.get('pairs_info'):
             logger.warning(f"Omitiendo escenario '{scenario_id}': No contiene relés o pares de información válidos después del procesamiento inicial.")
             failed_scenarios += 1
             continue
        try:
            optimized_settings_for_scenario = run_scenario_optimization(
                scenario_id,
                scenario_data['pairs_info'],
                scenario_data['initial_settings'],
                scenario_data['relays']
            )
            if optimized_settings_for_scenario:
                 all_optimized_settings[scenario_id] = optimized_settings_for_scenario
                 successful_scenarios += 1
            else:
                 logger.warning(f"La optimización no produjo resultados para el escenario: {scenario_id}")
                 failed_scenarios += 1
        except Exception as e:
            logger.error(f"Error inesperado durante optimización del escenario {scenario_id}: {e}", exc_info=True)
            failed_scenarios += 1


    # Format output as list
    output_list = []
    if all_optimized_settings:
        logger.info(f"Optimización completada. Escenarios exitosos: {successful_scenarios}, Escenarios fallidos/omitidos: {failed_scenarios}.")
        logger.info("Formateando resultados optimizados en la estructura de lista deseada...")
        for scenario_id, optimized_settings in all_optimized_settings.items():
            # Use a consistent way to generate OID-like strings if needed for DB
            # generated_oid = ''.join(random.choices(string.hexdigits.lower(), k=24))
            # Or just use scenario_id and timestamp for uniqueness if OID isn't strictly required
            current_timestamp = datetime.now(timezone.utc).isoformat(timespec='microseconds').replace('+00:00', 'Z') # Ensure Z format
            list_entry = {
                # "_id": { "$oid": generated_oid }, # Uncomment if MongoDB OID structure is needed
                "scenario_id": scenario_id,
                "timestamp": current_timestamp,
                "relay_values": optimized_settings # Contains optimized {'RelayName': {'TDS': x, 'pickup': y}}
            }
            output_list.append(list_entry)
        logger.info(f"Formato de lista creado con {len(output_list)} escenarios optimizados.")

        # Save the list
        try:
            output_dir = os.path.dirname(OPTIMIZED_SETTINGS_OUTPUT_PATH)
            if output_dir: os.makedirs(output_dir, exist_ok=True)
            # Use allow_nan=False to ensure compatibility with standard JSON (NaN/Infinity are not valid JSON)
            # Python's None will be converted to JSON null
            with open(OPTIMIZED_SETTINGS_OUTPUT_PATH, 'w') as file:
                json.dump(output_list, file, indent=2, allow_nan=False)
            logger.info(f"Archivo con ajustes optimizados (v4, MT>=-0.009, null handling) guardado en: {OPTIMIZED_SETTINGS_OUTPUT_PATH}")
        except Exception as e:
             logger.error(f"Error al guardar el archivo de salida {OPTIMIZED_SETTINGS_OUTPUT_PATH}: {e}")
    else:
        logger.error(f"La optimización falló o no produjo resultados para ningún escenario ({successful_scenarios} exitosos, {failed_scenarios} fallidos/omitidos). No se guardó ningún archivo.")

    logger.info("--- Script de Optimización Finalizado ---")
# Out:
# 2025-04-21 10:15:37,494 - INFO - --- Iniciando Script de Optimización de Ajustes de Relés (v4 - MT Threshold -0.009) ---
# 2025-04-21 10:15:37,624 - INFO - Archivo cargado: /Users/gustavo/Documents/Projects/TESIS_UNAL/ADAPTIVE_ALGORITHM/data/processed/independent_relay_pairs_automation.json
# 2025-04-21 10:15:37,683 - INFO - Datos agrupados por escenario. Pares procesados: 6720, Pares omitidos: 80
# 2025-04-21 10:15:37,731 - INFO - --- Iniciando optimización para scenario_1 ---
# 2025-04-21 10:15:37,750 - INFO - (scenario_1) Iter 1/250: OF=50.6909, TMT=-17.8087, MaxNegMT=-0.2309, Errors=0
# 2025-04-21 10:15:37,824 - INFO - (scenario_1) Iter 25/250: OF=46.9423, TMT=-11.4904, MaxNegMT=-0.6319, Errors=0
# 2025-04-21 10:15:37,844 - INFO - (scenario_1) Iter 50/250: OF=24.7190, TMT=-7.6346, MaxNegMT=-0.2529, Errors=0
# 2025-04-21 10:15:37,855 - INFO - (scenario_1) Iter 75/250: OF=29.3660, TMT=-5.9660, MaxNegMT=-0.3376, Errors=0
# 2025-04-21 10:15:38,381 - INFO - (scenario_1) Iter 100/250: OF=29.5074, TMT=-4.3521, MaxNegMT=-0.3992, Errors=0
# 2025-04-21 10:15:38,422 - INFO - (scenario_1) Iter 125/250: OF=30.1064, TMT=-4.1423, MaxNegMT=-0.3555, Errors=0
# 2025-04-21 10:15:38,623 - INFO - (scenario_1) Iter 150/250: OF=28.2693, TMT=-3.2329, MaxNegMT=-0.3813, Errors=0
# 2025-04-21 10:15:38,655 - INFO - (scenario_1) Iter 175/250: OF=30.0586, TMT=-2.7672, MaxNegMT=-0.4991, Errors=0
# 2025-04-21 10:15:38,680 - INFO - (scenario_1) Iter 200/250: OF=20.7592, TMT=-0.8314, MaxNegMT=-0.1390, Errors=0
# 2025-04-21 10:15:38,710 - INFO - (scenario_1) Iter 225/250: OF=20.6011, TMT=-0.7928, MaxNegMT=-0.1390, Errors=0
# 2025-04-21 10:15:38,755 - INFO - (scenario_1) Iter 250/250: OF=20.5721, TMT=-0.7300, MaxNegMT=-0.1390, Errors=0
# 2025-04-21 10:15:38,756 - WARNING - (scenario_1) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:38,757 - WARNING - (scenario_1) Estado final: TMT=-0.7300, MaxNegMT=-0.1390, Errors=0
# 2025-04-21 10:15:38,760 - INFO - --- Optimización finalizada para scenario_1 ---
# 2025-04-21 10:15:38,761 - INFO - --- Iniciando optimización para scenario_2 ---
# 2025-04-21 10:15:38,763 - INFO - (scenario_2) Iter 1/250: OF=48.1594, TMT=-15.5346, MaxNegMT=-0.5859, Errors=0
# 2025-04-21 10:15:38,799 - INFO - (scenario_2) Iter 25/250: OF=32.0057, TMT=-8.1114, MaxNegMT=-0.3853, Errors=0
# 2025-04-21 10:15:38,838 - INFO - (scenario_2) Iter 50/250: OF=16.3670, TMT=-3.6072, MaxNegMT=-0.2900, Errors=0
# 2025-04-21 10:15:38,879 - INFO - (scenario_2) Iter 75/250: OF=14.2984, TMT=-1.3541, MaxNegMT=-0.1018, Errors=0
# 2025-04-21 10:15:38,923 - INFO - (scenario_2) Iter 100/250: OF=14.8008, TMT=-0.2869, MaxNegMT=-0.0510, Errors=0
# 2025-04-21 10:15:39,207 - INFO - (scenario_2) Iter 122/250: OF=14.9170, TMT=0.0000, MaxNegMT=0.0000, Errors=0
# 2025-04-21 10:15:39,210 - INFO - (scenario_2) Convergencia alcanzada (TMT=0.0000 >= -0.005, MaxNegMT=0.0000 >= -0.009).
# 2025-04-21 10:15:39,212 - INFO - --- Optimización finalizada para scenario_2 ---
# 2025-04-21 10:15:39,213 - INFO - --- Iniciando optimización para scenario_3 ---
# 2025-04-21 10:15:39,214 - INFO - (scenario_3) Iter 1/250: OF=44.7548, TMT=-15.3306, MaxNegMT=-0.3419, Errors=0
# 2025-04-21 10:15:39,375 - INFO - (scenario_3) Iter 25/250: OF=28.6383, TMT=-8.0914, MaxNegMT=-0.4162, Errors=0
# 2025-04-21 10:15:39,407 - INFO - (scenario_3) Iter 50/250: OF=15.2839, TMT=-3.4997, MaxNegMT=-0.2202, Errors=0
# 2025-04-21 10:15:39,462 - INFO - (scenario_3) Iter 75/250: OF=14.2864, TMT=-1.3599, MaxNegMT=-0.1465, Errors=0
# 2025-04-21 10:15:39,474 - INFO - (scenario_3) Iter 100/250: OF=14.5197, TMT=-0.2411, MaxNegMT=-0.0676, Errors=0
# 2025-04-21 10:15:39,512 - INFO - (scenario_3) Iter 125/250: OF=15.4859, TMT=-0.3170, MaxNegMT=-0.1603, Errors=0
# 2025-04-21 10:15:39,545 - INFO - (scenario_3) Iter 150/250: OF=15.1569, TMT=-0.1481, MaxNegMT=-0.0717, Errors=0
# 2025-04-21 10:15:39,554 - INFO - (scenario_3) Iter 162/250: OF=14.9652, TMT=0.0000, MaxNegMT=0.0000, Errors=0
# 2025-04-21 10:15:39,557 - INFO - (scenario_3) Convergencia alcanzada (TMT=0.0000 >= -0.005, MaxNegMT=0.0000 >= -0.009).
# 2025-04-21 10:15:39,559 - INFO - --- Optimización finalizada para scenario_3 ---
# 2025-04-21 10:15:39,561 - INFO - --- Iniciando optimización para scenario_4 ---
# 2025-04-21 10:15:39,562 - INFO - (scenario_4) Iter 1/250: OF=49.7455, TMT=-17.4487, MaxNegMT=-0.2208, Errors=0
# 2025-04-21 10:15:39,733 - INFO - (scenario_4) Iter 25/250: OF=43.9061, TMT=-10.5951, MaxNegMT=-0.5340, Errors=0
# 2025-04-21 10:15:40,086 - INFO - (scenario_4) Iter 50/250: OF=20.9770, TMT=-6.0277, MaxNegMT=-0.2262, Errors=0
# 2025-04-21 10:15:40,130 - INFO - (scenario_4) Iter 75/250: OF=28.4636, TMT=-5.2370, MaxNegMT=-0.3806, Errors=0
# 2025-04-21 10:15:40,182 - INFO - (scenario_4) Iter 100/250: OF=25.5588, TMT=-3.3768, MaxNegMT=-0.2938, Errors=0
# 2025-04-21 10:15:40,193 - INFO - (scenario_4) Iter 125/250: OF=21.5265, TMT=-1.8877, MaxNegMT=-0.2557, Errors=0
# 2025-04-21 10:15:40,221 - INFO - (scenario_4) Iter 150/250: OF=24.1283, TMT=-1.5616, MaxNegMT=-0.4691, Errors=0
# 2025-04-21 10:15:40,237 - INFO - (scenario_4) Iter 175/250: OF=20.2498, TMT=-1.1041, MaxNegMT=-0.2411, Errors=0
# 2025-04-21 10:15:40,258 - INFO - (scenario_4) Iter 200/250: OF=25.0768, TMT=-2.3459, MaxNegMT=-0.3442, Errors=0
# 2025-04-21 10:15:40,275 - INFO - (scenario_4) Iter 225/250: OF=19.7522, TMT=-0.6299, MaxNegMT=-0.1489, Errors=0
# 2025-04-21 10:15:40,296 - INFO - (scenario_4) Iter 250/250: OF=19.5887, TMT=-0.5581, MaxNegMT=-0.1278, Errors=0
# 2025-04-21 10:15:40,297 - WARNING - (scenario_4) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:40,298 - WARNING - (scenario_4) Estado final: TMT=-0.5581, MaxNegMT=-0.1278, Errors=0
# 2025-04-21 10:15:40,300 - INFO - --- Optimización finalizada para scenario_4 ---
# 2025-04-21 10:15:40,303 - INFO - --- Iniciando optimización para scenario_5 ---
# 2025-04-21 10:15:40,312 - INFO - (scenario_5) Iter 1/250: OF=52.6136, TMT=-15.4373, MaxNegMT=-0.8594, Errors=0
# 2025-04-21 10:15:40,386 - INFO - (scenario_5) Iter 25/250: OF=35.9475, TMT=-8.2981, MaxNegMT=-0.5907, Errors=0
# 2025-04-21 10:15:40,500 - INFO - (scenario_5) Iter 50/250: OF=16.9591, TMT=-3.4280, MaxNegMT=-0.2960, Errors=0
# 2025-04-21 10:15:40,545 - INFO - (scenario_5) Iter 75/250: OF=17.2875, TMT=-1.9126, MaxNegMT=-0.2532, Errors=0
# 2025-04-21 10:15:40,576 - INFO - (scenario_5) Iter 100/250: OF=14.8394, TMT=-0.1741, MaxNegMT=-0.0691, Errors=0
# 2025-04-21 10:15:40,614 - INFO - (scenario_5) Iter 112/250: OF=14.8502, TMT=0.0000, MaxNegMT=0.0000, Errors=0
# 2025-04-21 10:15:40,616 - INFO - (scenario_5) Convergencia alcanzada (TMT=0.0000 >= -0.005, MaxNegMT=0.0000 >= -0.009).
# 2025-04-21 10:15:40,620 - INFO - --- Optimización finalizada para scenario_5 ---
# 2025-04-21 10:15:40,622 - INFO - --- Iniciando optimización para scenario_6 ---
# 2025-04-21 10:15:40,624 - INFO - (scenario_6) Iter 1/250: OF=47.9736, TMT=-15.2916, MaxNegMT=-0.6472, Errors=0
# 2025-04-21 10:15:40,692 - INFO - (scenario_6) Iter 25/250: OF=31.5141, TMT=-8.2508, MaxNegMT=-0.4183, Errors=0
# 2025-04-21 10:15:40,743 - INFO - (scenario_6) Iter 50/250: OF=16.5081, TMT=-3.8040, MaxNegMT=-0.2654, Errors=0
# 2025-04-21 10:15:40,755 - INFO - (scenario_6) Iter 75/250: OF=14.8751, TMT=-1.3061, MaxNegMT=-0.2537, Errors=0
# 2025-04-21 10:15:40,775 - INFO - (scenario_6) Iter 100/250: OF=14.7821, TMT=-0.3085, MaxNegMT=-0.0557, Errors=0
# 2025-04-21 10:15:40,786 - INFO - (scenario_6) Iter 116/250: OF=14.9588, TMT=-0.0008, MaxNegMT=-0.0008, Errors=0
# 2025-04-21 10:15:40,787 - INFO - (scenario_6) Convergencia alcanzada (TMT=-0.0008 >= -0.005, MaxNegMT=-0.0008 >= -0.009).
# 2025-04-21 10:15:40,789 - INFO - --- Optimización finalizada para scenario_6 ---
# 2025-04-21 10:15:40,790 - INFO - --- Iniciando optimización para scenario_7 ---
# 2025-04-21 10:15:40,794 - INFO - (scenario_7) Iter 1/250: OF=45.9110, TMT=-15.4197, MaxNegMT=-0.4390, Errors=0
# 2025-04-21 10:15:40,843 - INFO - (scenario_7) Iter 25/250: OF=30.4879, TMT=-8.0895, MaxNegMT=-0.4131, Errors=0
# 2025-04-21 10:15:40,855 - INFO - (scenario_7) Iter 50/250: OF=15.5097, TMT=-3.2627, MaxNegMT=-0.2031, Errors=0
# 2025-04-21 10:15:40,875 - INFO - (scenario_7) Iter 75/250: OF=16.8291, TMT=-2.0743, MaxNegMT=-0.2233, Errors=0
# 2025-04-21 10:15:40,932 - INFO - (scenario_7) Iter 100/250: OF=14.8873, TMT=-0.1822, MaxNegMT=-0.0721, Errors=0
# 2025-04-21 10:15:40,945 - INFO - (scenario_7) Iter 109/250: OF=14.8960, TMT=-0.0015, MaxNegMT=-0.0015, Errors=0
# 2025-04-21 10:15:40,945 - INFO - (scenario_7) Convergencia alcanzada (TMT=-0.0015 >= -0.005, MaxNegMT=-0.0015 >= -0.009).
# 2025-04-21 10:15:40,946 - INFO - --- Optimización finalizada para scenario_7 ---
# 2025-04-21 10:15:40,947 - INFO - --- Iniciando optimización para scenario_8 ---
# 2025-04-21 10:15:40,947 - INFO - (scenario_8) Iter 1/250: OF=48.8172, TMT=-15.6394, MaxNegMT=-0.5930, Errors=0
# 2025-04-21 10:15:41,079 - INFO - (scenario_8) Iter 25/250: OF=29.5631, TMT=-7.9097, MaxNegMT=-0.3794, Errors=0
# 2025-04-21 10:15:41,123 - INFO - (scenario_8) Iter 50/250: OF=14.7331, TMT=-3.2594, MaxNegMT=-0.2759, Errors=0
# 2025-04-21 10:15:41,147 - INFO - (scenario_8) Iter 75/250: OF=23.4470, TMT=-3.4933, MaxNegMT=-0.3119, Errors=0
# 2025-04-21 10:15:41,178 - INFO - (scenario_8) Iter 100/250: OF=14.8725, TMT=-0.1851, MaxNegMT=-0.0732, Errors=0
# 2025-04-21 10:15:41,254 - INFO - (scenario_8) Iter 111/250: OF=14.8089, TMT=0.0000, MaxNegMT=0.0000, Errors=0
# 2025-04-21 10:15:41,256 - INFO - (scenario_8) Convergencia alcanzada (TMT=0.0000 >= -0.005, MaxNegMT=0.0000 >= -0.009).
# 2025-04-21 10:15:41,260 - INFO - --- Optimización finalizada para scenario_8 ---
# 2025-04-21 10:15:41,261 - INFO - --- Iniciando optimización para scenario_9 ---
# 2025-04-21 10:15:41,270 - INFO - (scenario_9) Iter 1/250: OF=44.0548, TMT=-14.8245, MaxNegMT=-0.3202, Errors=0
# 2025-04-21 10:15:41,295 - INFO - (scenario_9) Iter 25/250: OF=28.3989, TMT=-7.8090, MaxNegMT=-0.3751, Errors=0
# 2025-04-21 10:15:41,379 - INFO - (scenario_9) Iter 50/250: OF=14.3774, TMT=-2.8045, MaxNegMT=-0.2232, Errors=0
# 2025-04-21 10:15:41,432 - INFO - (scenario_9) Iter 75/250: OF=15.2507, TMT=-1.2169, MaxNegMT=-0.2847, Errors=0
# 2025-04-21 10:15:41,463 - INFO - (scenario_9) Iter 100/250: OF=14.0359, TMT=-0.0773, MaxNegMT=-0.0220, Errors=0
# 2025-04-21 10:15:41,473 - INFO - (scenario_9) Iter 111/250: OF=14.0658, TMT=0.0000, MaxNegMT=0.0000, Errors=0
# 2025-04-21 10:15:41,474 - INFO - (scenario_9) Convergencia alcanzada (TMT=0.0000 >= -0.005, MaxNegMT=0.0000 >= -0.009).
# 2025-04-21 10:15:41,479 - INFO - --- Optimización finalizada para scenario_9 ---
# 2025-04-21 10:15:41,480 - INFO - --- Iniciando optimización para scenario_10 ---
# 2025-04-21 10:15:41,484 - INFO - (scenario_10) Iter 1/250: OF=43.3319, TMT=-14.8862, MaxNegMT=-0.2730, Errors=0
# 2025-04-21 10:15:41,524 - INFO - (scenario_10) Iter 25/250: OF=30.1902, TMT=-7.7825, MaxNegMT=-0.4521, Errors=0
# 2025-04-21 10:15:41,745 - INFO - (scenario_10) Iter 50/250: OF=14.7608, TMT=-3.1747, MaxNegMT=-0.1939, Errors=0
# 2025-04-21 10:15:41,799 - INFO - (scenario_10) Iter 75/250: OF=17.3270, TMT=-1.9770, MaxNegMT=-0.2507, Errors=0
# 2025-04-21 10:15:41,872 - INFO - (scenario_10) Iter 100/250: OF=14.5263, TMT=-0.0584, MaxNegMT=-0.0224, Errors=0
# 2025-04-21 10:15:41,890 - INFO - (scenario_10) Iter 111/250: OF=14.6784, TMT=0.0000, MaxNegMT=0.0000, Errors=0
# 2025-04-21 10:15:41,891 - INFO - (scenario_10) Convergencia alcanzada (TMT=0.0000 >= -0.005, MaxNegMT=0.0000 >= -0.009).
# 2025-04-21 10:15:41,893 - INFO - --- Optimización finalizada para scenario_10 ---
# 2025-04-21 10:15:41,894 - INFO - --- Iniciando optimización para scenario_11 ---
# 2025-04-21 10:15:41,899 - INFO - (scenario_11) Iter 1/250: OF=43.5621, TMT=-15.1340, MaxNegMT=-0.2698, Errors=0
# 2025-04-21 10:15:41,967 - INFO - (scenario_11) Iter 25/250: OF=29.2684, TMT=-8.1733, MaxNegMT=-0.4061, Errors=0
# 2025-04-21 10:15:41,982 - INFO - (scenario_11) Iter 50/250: OF=15.5195, TMT=-3.5198, MaxNegMT=-0.2771, Errors=0
# 2025-04-21 10:15:42,050 - INFO - (scenario_11) Iter 75/250: OF=19.0476, TMT=-2.3760, MaxNegMT=-0.2711, Errors=0
# 2025-04-21 10:15:42,070 - INFO - (scenario_11) Iter 100/250: OF=14.7660, TMT=-0.1679, MaxNegMT=-0.0551, Errors=0
# 2025-04-21 10:15:42,085 - INFO - (scenario_11) Iter 125/250: OF=14.8370, TMT=-0.0778, MaxNegMT=-0.0778, Errors=0
# 2025-04-21 10:15:42,106 - INFO - (scenario_11) Iter 150/250: OF=14.8227, TMT=-0.0961, MaxNegMT=-0.0544, Errors=0
# 2025-04-21 10:15:42,236 - INFO - (scenario_11) Iter 175/250: OF=14.7670, TMT=-0.0359, MaxNegMT=-0.0309, Errors=0
# 2025-04-21 10:15:42,305 - INFO - (scenario_11) Iter 200/250: OF=14.7914, TMT=-0.0601, MaxNegMT=-0.0544, Errors=0
# 2025-04-21 10:15:42,377 - INFO - (scenario_11) Iter 225/250: OF=14.8530, TMT=-0.0816, MaxNegMT=-0.0778, Errors=0
# 2025-04-21 10:15:42,387 - INFO - (scenario_11) Iter 250/250: OF=14.8100, TMT=-0.0824, MaxNegMT=-0.0544, Errors=0
# 2025-04-21 10:15:42,387 - WARNING - (scenario_11) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:42,388 - WARNING - (scenario_11) Estado final: TMT=-0.0824, MaxNegMT=-0.0544, Errors=0
# 2025-04-21 10:15:42,397 - INFO - --- Optimización finalizada para scenario_11 ---
# 2025-04-21 10:15:42,411 - INFO - --- Iniciando optimización para scenario_12 ---
# 2025-04-21 10:15:42,420 - INFO - (scenario_12) Iter 1/250: OF=45.0286, TMT=-15.2963, MaxNegMT=-0.3974, Errors=0
# 2025-04-21 10:15:42,464 - INFO - (scenario_12) Iter 25/250: OF=28.0811, TMT=-7.8523, MaxNegMT=-0.3969, Errors=0
# 2025-04-21 10:15:42,489 - INFO - (scenario_12) Iter 50/250: OF=16.0771, TMT=-3.7538, MaxNegMT=-0.2459, Errors=0
# 2025-04-21 10:15:42,504 - INFO - (scenario_12) Iter 75/250: OF=18.1760, TMT=-2.3233, MaxNegMT=-0.2929, Errors=0
# 2025-04-21 10:15:42,522 - INFO - (scenario_12) Iter 100/250: OF=14.7487, TMT=-0.1528, MaxNegMT=-0.0585, Errors=0
# 2025-04-21 10:15:42,538 - INFO - (scenario_12) Iter 111/250: OF=14.7850, TMT=-0.0037, MaxNegMT=-0.0037, Errors=0
# 2025-04-21 10:15:42,540 - INFO - (scenario_12) Convergencia alcanzada (TMT=-0.0037 >= -0.005, MaxNegMT=-0.0037 >= -0.009).
# 2025-04-21 10:15:42,550 - INFO - --- Optimización finalizada para scenario_12 ---
# 2025-04-21 10:15:42,551 - INFO - --- Iniciando optimización para scenario_13 ---
# 2025-04-21 10:15:42,552 - INFO - (scenario_13) Iter 1/250: OF=42.0942, TMT=-14.4511, MaxNegMT=-0.2685, Errors=0
# 2025-04-21 10:15:42,690 - INFO - (scenario_13) Iter 25/250: OF=26.0695, TMT=-7.2609, MaxNegMT=-0.4192, Errors=0
# 2025-04-21 10:15:42,729 - INFO - (scenario_13) Iter 50/250: OF=15.6216, TMT=-3.1533, MaxNegMT=-0.2333, Errors=0
# 2025-04-21 10:15:42,743 - INFO - (scenario_13) Iter 75/250: OF=14.1204, TMT=-0.9359, MaxNegMT=-0.2646, Errors=0
# 2025-04-21 10:15:42,758 - INFO - (scenario_13) Iter 100/250: OF=13.9227, TMT=-0.0382, MaxNegMT=-0.0230, Errors=0
# 2025-04-21 10:15:42,762 - INFO - (scenario_13) Iter 105/250: OF=13.9375, TMT=-0.0007, MaxNegMT=-0.0007, Errors=0
# 2025-04-21 10:15:42,763 - INFO - (scenario_13) Convergencia alcanzada (TMT=-0.0007 >= -0.005, MaxNegMT=-0.0007 >= -0.009).
# 2025-04-21 10:15:42,765 - INFO - --- Optimización finalizada para scenario_13 ---
# 2025-04-21 10:15:42,767 - INFO - --- Iniciando optimización para scenario_14 ---
# 2025-04-21 10:15:42,770 - INFO - (scenario_14) Iter 1/250: OF=42.2984, TMT=-14.5011, MaxNegMT=-0.2849, Errors=0
# 2025-04-21 10:15:42,814 - INFO - (scenario_14) Iter 25/250: OF=27.7129, TMT=-7.3534, MaxNegMT=-0.4559, Errors=0
# 2025-04-21 10:15:42,831 - INFO - (scenario_14) Iter 50/250: OF=14.3959, TMT=-2.5605, MaxNegMT=-0.2823, Errors=0
# 2025-04-21 10:15:42,900 - INFO - (scenario_14) Iter 75/250: OF=12.9682, TMT=-0.6708, MaxNegMT=-0.0855, Errors=0
# 2025-04-21 10:15:42,914 - INFO - (scenario_14) Iter 100/250: OF=13.5154, TMT=-0.0736, MaxNegMT=-0.0510, Errors=0
# 2025-04-21 10:15:42,921 - INFO - (scenario_14) Iter 102/250: OF=13.4894, TMT=0.0000, MaxNegMT=0.0000, Errors=0
# 2025-04-21 10:15:42,922 - INFO - (scenario_14) Convergencia alcanzada (TMT=0.0000 >= -0.005, MaxNegMT=0.0000 >= -0.009).
# 2025-04-21 10:15:42,924 - INFO - --- Optimización finalizada para scenario_14 ---
# 2025-04-21 10:15:42,927 - INFO - --- Iniciando optimización para scenario_15 ---
# 2025-04-21 10:15:42,928 - INFO - (scenario_15) Iter 1/250: OF=41.8141, TMT=-14.5624, MaxNegMT=-0.2323, Errors=0
# 2025-04-21 10:15:43,065 - INFO - (scenario_15) Iter 25/250: OF=26.9025, TMT=-7.4251, MaxNegMT=-0.3870, Errors=0
# 2025-04-21 10:15:43,106 - INFO - (scenario_15) Iter 50/250: OF=16.6206, TMT=-3.4629, MaxNegMT=-0.2735, Errors=0
# 2025-04-21 10:15:43,132 - INFO - (scenario_15) Iter 75/250: OF=17.0105, TMT=-2.0689, MaxNegMT=-0.2454, Errors=0
# 2025-04-21 10:15:43,181 - INFO - (scenario_15) Iter 100/250: OF=14.2939, TMT=-0.0911, MaxNegMT=-0.0588, Errors=0
# 2025-04-21 10:15:43,186 - INFO - (scenario_15) Iter 108/250: OF=14.3112, TMT=0.0000, MaxNegMT=0.0000, Errors=0
# 2025-04-21 10:15:43,188 - INFO - (scenario_15) Convergencia alcanzada (TMT=0.0000 >= -0.005, MaxNegMT=0.0000 >= -0.009).
# 2025-04-21 10:15:43,191 - INFO - --- Optimización finalizada para scenario_15 ---
# 2025-04-21 10:15:43,199 - INFO - --- Iniciando optimización para scenario_16 ---
# 2025-04-21 10:15:43,201 - INFO - (scenario_16) Iter 1/250: OF=41.9533, TMT=-14.5973, MaxNegMT=-0.2403, Errors=0
# 2025-04-21 10:15:43,235 - INFO - (scenario_16) Iter 25/250: OF=29.2740, TMT=-7.4523, MaxNegMT=-0.4131, Errors=0
# 2025-04-21 10:15:43,250 - INFO - (scenario_16) Iter 50/250: OF=18.5693, TMT=-3.7132, MaxNegMT=-0.3404, Errors=0
# 2025-04-21 10:15:43,269 - INFO - (scenario_16) Iter 75/250: OF=13.1295, TMT=-0.7870, MaxNegMT=-0.0685, Errors=0
# 2025-04-21 10:15:43,293 - INFO - (scenario_16) Iter 100/250: OF=14.1354, TMT=-0.0909, MaxNegMT=-0.0478, Errors=0
# 2025-04-21 10:15:43,306 - INFO - (scenario_16) Iter 110/250: OF=14.1566, TMT=-0.0008, MaxNegMT=-0.0008, Errors=0
# 2025-04-21 10:15:43,307 - INFO - (scenario_16) Convergencia alcanzada (TMT=-0.0008 >= -0.005, MaxNegMT=-0.0008 >= -0.009).
# 2025-04-21 10:15:43,308 - INFO - --- Optimización finalizada para scenario_16 ---
# 2025-04-21 10:15:43,308 - INFO - --- Iniciando optimización para scenario_17 ---
# 2025-04-21 10:15:43,309 - INFO - (scenario_17) Iter 1/250: OF=43.7656, TMT=-15.1974, MaxNegMT=-0.2643, Errors=0
# 2025-04-21 10:15:43,355 - INFO - (scenario_17) Iter 25/250: OF=32.0045, TMT=-8.2772, MaxNegMT=-0.4450, Errors=0
# 2025-04-21 10:15:43,462 - INFO - (scenario_17) Iter 50/250: OF=15.3674, TMT=-3.3349, MaxNegMT=-0.2771, Errors=0
# 2025-04-21 10:15:43,515 - INFO - (scenario_17) Iter 75/250: OF=14.3708, TMT=-1.3312, MaxNegMT=-0.1729, Errors=0
# 2025-04-21 10:15:43,550 - INFO - (scenario_17) Iter 100/250: OF=14.8463, TMT=-0.2900, MaxNegMT=-0.0444, Errors=0
# 2025-04-21 10:15:43,572 - INFO - (scenario_17) Iter 125/250: OF=19.3385, TMT=-1.0208, MaxNegMT=-0.3593, Errors=0
# 2025-04-21 10:15:43,598 - INFO - (scenario_17) Iter 150/250: OF=15.4331, TMT=-0.0837, MaxNegMT=-0.0837, Errors=0
# 2025-04-21 10:15:43,610 - INFO - (scenario_17) Iter 175/250: OF=15.3177, TMT=-0.0471, MaxNegMT=-0.0297, Errors=0
# 2025-04-21 10:15:43,624 - INFO - (scenario_17) Iter 200/250: OF=15.3082, TMT=-0.0351, MaxNegMT=-0.0351, Errors=0
# 2025-04-21 10:15:43,626 - INFO - (scenario_17) Iter 205/250: OF=15.2826, TMT=0.0000, MaxNegMT=0.0000, Errors=0
# 2025-04-21 10:15:43,627 - INFO - (scenario_17) Convergencia alcanzada (TMT=0.0000 >= -0.005, MaxNegMT=0.0000 >= -0.009).
# 2025-04-21 10:15:43,630 - INFO - --- Optimización finalizada para scenario_17 ---
# 2025-04-21 10:15:43,635 - INFO - --- Iniciando optimización para scenario_18 ---
# 2025-04-21 10:15:43,684 - INFO - (scenario_18) Iter 1/250: OF=44.6584, TMT=-15.2774, MaxNegMT=-0.3383, Errors=0
# 2025-04-21 10:15:43,717 - INFO - (scenario_18) Iter 25/250: OF=31.7725, TMT=-8.2622, MaxNegMT=-0.4381, Errors=0
# 2025-04-21 10:15:43,740 - INFO - (scenario_18) Iter 50/250: OF=18.4360, TMT=-3.7216, MaxNegMT=-0.3349, Errors=0
# 2025-04-21 10:15:43,750 - INFO - (scenario_18) Iter 75/250: OF=17.5509, TMT=-1.9650, MaxNegMT=-0.2851, Errors=0
# 2025-04-21 10:15:43,764 - INFO - (scenario_18) Iter 100/250: OF=14.6958, TMT=-0.2634, MaxNegMT=-0.0511, Errors=0
# 2025-04-21 10:15:43,941 - INFO - (scenario_18) Iter 125/250: OF=14.9455, TMT=-0.0774, MaxNegMT=-0.0738, Errors=0
# 2025-04-21 10:15:43,954 - INFO - (scenario_18) Iter 150/250: OF=14.9922, TMT=-0.0968, MaxNegMT=-0.0968, Errors=0
# 2025-04-21 10:15:44,052 - INFO - (scenario_18) Iter 175/250: OF=14.9762, TMT=-0.1327, MaxNegMT=-0.0738, Errors=0
# 2025-04-21 10:15:44,061 - INFO - (scenario_18) Iter 200/250: OF=14.9049, TMT=-0.0534, MaxNegMT=-0.0508, Errors=0
# 2025-04-21 10:15:44,087 - INFO - (scenario_18) Iter 225/250: OF=14.9552, TMT=-0.0761, MaxNegMT=-0.0738, Errors=0
# 2025-04-21 10:15:44,095 - INFO - (scenario_18) Iter 250/250: OF=15.0146, TMT=-0.1000, MaxNegMT=-0.0968, Errors=0
# 2025-04-21 10:15:44,096 - WARNING - (scenario_18) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:44,097 - WARNING - (scenario_18) Estado final: TMT=-0.1000, MaxNegMT=-0.0968, Errors=0
# 2025-04-21 10:15:44,100 - INFO - --- Optimización finalizada para scenario_18 ---
# 2025-04-21 10:15:44,103 - INFO - --- Iniciando optimización para scenario_19 ---
# 2025-04-21 10:15:44,106 - INFO - (scenario_19) Iter 1/250: OF=44.7707, TMT=-15.3314, MaxNegMT=-0.3577, Errors=0
# 2025-04-21 10:15:44,153 - INFO - (scenario_19) Iter 25/250: OF=30.9036, TMT=-8.0165, MaxNegMT=-0.4068, Errors=0
# 2025-04-21 10:15:44,180 - INFO - (scenario_19) Iter 50/250: OF=17.4377, TMT=-4.0349, MaxNegMT=-0.2142, Errors=0
# 2025-04-21 10:15:44,197 - INFO - (scenario_19) Iter 75/250: OF=14.5279, TMT=-1.3048, MaxNegMT=-0.1920, Errors=0
# 2025-04-21 10:15:44,216 - INFO - (scenario_19) Iter 100/250: OF=14.8178, TMT=-0.2445, MaxNegMT=-0.0738, Errors=0
# 2025-04-21 10:15:44,361 - INFO - (scenario_19) Iter 125/250: OF=14.7895, TMT=-0.0516, MaxNegMT=-0.0516, Errors=0
# 2025-04-21 10:15:44,435 - INFO - (scenario_19) Iter 150/250: OF=14.8450, TMT=-0.0749, MaxNegMT=-0.0749, Errors=0
# 2025-04-21 10:15:44,464 - INFO - (scenario_19) Iter 175/250: OF=14.7576, TMT=-0.0363, MaxNegMT=-0.0296, Errors=0
# 2025-04-21 10:15:44,481 - INFO - (scenario_19) Iter 200/250: OF=14.7610, TMT=-0.0529, MaxNegMT=-0.0283, Errors=0
# 2025-04-21 10:15:44,500 - INFO - (scenario_19) Iter 225/250: OF=14.7487, TMT=-0.0440, MaxNegMT=-0.0253, Errors=0
# 2025-04-21 10:15:44,523 - INFO - (scenario_19) Iter 250/250: OF=14.7422, TMT=-0.0283, MaxNegMT=-0.0283, Errors=0
# 2025-04-21 10:15:44,524 - WARNING - (scenario_19) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:44,526 - WARNING - (scenario_19) Estado final: TMT=-0.0283, MaxNegMT=-0.0283, Errors=0
# 2025-04-21 10:15:44,528 - INFO - --- Optimización finalizada para scenario_19 ---
# 2025-04-21 10:15:44,528 - INFO - --- Iniciando optimización para scenario_20 ---
# 2025-04-21 10:15:44,530 - INFO - (scenario_20) Iter 1/250: OF=46.5164, TMT=-15.4718, MaxNegMT=-0.4729, Errors=0
# 2025-04-21 10:15:44,587 - INFO - (scenario_20) Iter 25/250: OF=29.9816, TMT=-8.3427, MaxNegMT=-0.4160, Errors=0
# 2025-04-21 10:15:44,670 - INFO - (scenario_20) Iter 50/250: OF=16.8798, TMT=-3.7765, MaxNegMT=-0.2441, Errors=0
# 2025-04-21 10:15:44,773 - INFO - (scenario_20) Iter 75/250: OF=19.7662, TMT=-2.7088, MaxNegMT=-0.2863, Errors=0
# 2025-04-21 10:15:44,872 - INFO - (scenario_20) Iter 100/250: OF=15.1033, TMT=-0.2849, MaxNegMT=-0.0831, Errors=0
# 2025-04-21 10:15:44,963 - INFO - (scenario_20) Iter 121/250: OF=15.1409, TMT=-0.0029, MaxNegMT=-0.0029, Errors=0
# 2025-04-21 10:15:44,966 - INFO - (scenario_20) Convergencia alcanzada (TMT=-0.0029 >= -0.005, MaxNegMT=-0.0029 >= -0.009).
# 2025-04-21 10:15:44,978 - INFO - --- Optimización finalizada para scenario_20 ---
# 2025-04-21 10:15:44,987 - INFO - --- Iniciando optimización para scenario_21 ---
# 2025-04-21 10:15:44,990 - INFO - (scenario_21) Iter 1/250: OF=50.7488, TMT=-17.7978, MaxNegMT=-0.2360, Errors=0
# 2025-04-21 10:15:45,022 - INFO - (scenario_21) Iter 25/250: OF=48.2965, TMT=-11.4309, MaxNegMT=-0.6263, Errors=0
# 2025-04-21 10:15:45,041 - INFO - (scenario_21) Iter 50/250: OF=25.0509, TMT=-7.8916, MaxNegMT=-0.3065, Errors=0
# 2025-04-21 10:15:45,056 - INFO - (scenario_21) Iter 75/250: OF=32.4331, TMT=-6.0732, MaxNegMT=-0.3878, Errors=0
# 2025-04-21 10:15:45,075 - INFO - (scenario_21) Iter 100/250: OF=34.3409, TMT=-5.3102, MaxNegMT=-0.4375, Errors=0
# 2025-04-21 10:15:45,090 - INFO - (scenario_21) Iter 125/250: OF=26.1780, TMT=-2.8714, MaxNegMT=-0.5004, Errors=0
# 2025-04-21 10:15:45,110 - INFO - (scenario_21) Iter 150/250: OF=26.4847, TMT=-2.8110, MaxNegMT=-0.3060, Errors=0
# 2025-04-21 10:15:45,128 - INFO - (scenario_21) Iter 175/250: OF=22.3087, TMT=-1.3585, MaxNegMT=-0.2895, Errors=0
# 2025-04-21 10:15:45,147 - INFO - (scenario_21) Iter 200/250: OF=23.0412, TMT=-1.5251, MaxNegMT=-0.2788, Errors=0
# 2025-04-21 10:15:45,238 - INFO - (scenario_21) Iter 225/250: OF=21.8120, TMT=-1.0537, MaxNegMT=-0.2742, Errors=0
# 2025-04-21 10:15:45,303 - INFO - (scenario_21) Iter 250/250: OF=19.7704, TMT=-0.3562, MaxNegMT=-0.0981, Errors=0
# 2025-04-21 10:15:45,308 - WARNING - (scenario_21) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:45,328 - WARNING - (scenario_21) Estado final: TMT=-0.3562, MaxNegMT=-0.0981, Errors=0
# 2025-04-21 10:15:45,330 - INFO - --- Optimización finalizada para scenario_21 ---
# 2025-04-21 10:15:45,333 - INFO - --- Iniciando optimización para scenario_22 ---
# 2025-04-21 10:15:45,337 - INFO - (scenario_22) Iter 1/250: OF=50.7595, TMT=-17.8023, MaxNegMT=-0.2399, Errors=0
# 2025-04-21 10:15:45,437 - INFO - (scenario_22) Iter 25/250: OF=45.2706, TMT=-11.4451, MaxNegMT=-0.5917, Errors=0
# 2025-04-21 10:15:45,465 - INFO - (scenario_22) Iter 50/250: OF=24.1853, TMT=-7.9145, MaxNegMT=-0.2317, Errors=0
# 2025-04-21 10:15:45,490 - INFO - (scenario_22) Iter 75/250: OF=32.2307, TMT=-6.0937, MaxNegMT=-0.3815, Errors=0
# 2025-04-21 10:15:45,502 - INFO - (scenario_22) Iter 100/250: OF=34.9363, TMT=-5.0014, MaxNegMT=-0.4859, Errors=0
# 2025-04-21 10:15:45,518 - INFO - (scenario_22) Iter 125/250: OF=27.4804, TMT=-3.3066, MaxNegMT=-0.3116, Errors=0
# 2025-04-21 10:15:45,597 - INFO - (scenario_22) Iter 150/250: OF=25.7196, TMT=-2.8187, MaxNegMT=-0.3135, Errors=0
# 2025-04-21 10:15:45,615 - INFO - (scenario_22) Iter 175/250: OF=24.5891, TMT=-1.6590, MaxNegMT=-0.2765, Errors=0
# 2025-04-21 10:15:45,629 - INFO - (scenario_22) Iter 200/250: OF=20.7938, TMT=-0.4850, MaxNegMT=-0.1426, Errors=0
# 2025-04-21 10:15:45,655 - INFO - (scenario_22) Iter 225/250: OF=20.6301, TMT=-0.4302, MaxNegMT=-0.1426, Errors=0
# 2025-04-21 10:15:45,665 - INFO - (scenario_22) Iter 250/250: OF=20.5753, TMT=-0.4209, MaxNegMT=-0.1426, Errors=0
# 2025-04-21 10:15:45,665 - WARNING - (scenario_22) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:45,666 - WARNING - (scenario_22) Estado final: TMT=-0.4209, MaxNegMT=-0.1426, Errors=0
# 2025-04-21 10:15:45,670 - INFO - --- Optimización finalizada para scenario_22 ---
# 2025-04-21 10:15:45,673 - INFO - --- Iniciando optimización para scenario_23 ---
# 2025-04-21 10:15:45,676 - INFO - (scenario_23) Iter 1/250: OF=50.5000, TMT=-17.7246, MaxNegMT=-0.2329, Errors=0
# 2025-04-21 10:15:45,857 - INFO - (scenario_23) Iter 25/250: OF=45.2386, TMT=-11.3848, MaxNegMT=-0.4932, Errors=0
# 2025-04-21 10:15:45,943 - INFO - (scenario_23) Iter 50/250: OF=23.7664, TMT=-7.4856, MaxNegMT=-0.2235, Errors=0
# 2025-04-21 10:15:45,965 - INFO - (scenario_23) Iter 75/250: OF=31.0205, TMT=-5.7597, MaxNegMT=-0.3212, Errors=0
# 2025-04-21 10:15:46,012 - INFO - (scenario_23) Iter 100/250: OF=22.4867, TMT=-2.8989, MaxNegMT=-0.3323, Errors=0
# 2025-04-21 10:15:46,026 - INFO - (scenario_23) Iter 125/250: OF=24.4818, TMT=-2.8552, MaxNegMT=-0.3189, Errors=0
# 2025-04-21 10:15:46,051 - INFO - (scenario_23) Iter 150/250: OF=22.4146, TMT=-2.4848, MaxNegMT=-0.2263, Errors=0
# 2025-04-21 10:15:46,076 - INFO - (scenario_23) Iter 175/250: OF=20.4129, TMT=-1.6847, MaxNegMT=-0.1490, Errors=0
# 2025-04-21 10:15:46,097 - INFO - (scenario_23) Iter 200/250: OF=20.1769, TMT=-1.6288, MaxNegMT=-0.1490, Errors=0
# 2025-04-21 10:15:46,108 - INFO - (scenario_23) Iter 225/250: OF=20.4402, TMT=-1.7365, MaxNegMT=-0.1490, Errors=0
# 2025-04-21 10:15:46,124 - INFO - (scenario_23) Iter 250/250: OF=20.0959, TMT=-1.5877, MaxNegMT=-0.1490, Errors=0
# 2025-04-21 10:15:46,125 - WARNING - (scenario_23) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:46,128 - WARNING - (scenario_23) Estado final: TMT=-1.5877, MaxNegMT=-0.1490, Errors=0
# 2025-04-21 10:15:46,138 - INFO - --- Optimización finalizada para scenario_23 ---
# 2025-04-21 10:15:46,140 - INFO - --- Iniciando optimización para scenario_24 ---
# 2025-04-21 10:15:46,141 - INFO - (scenario_24) Iter 1/250: OF=50.3499, TMT=-17.6549, MaxNegMT=-0.2332, Errors=0
# 2025-04-21 10:15:46,176 - INFO - (scenario_24) Iter 25/250: OF=43.4654, TMT=-11.1629, MaxNegMT=-0.4892, Errors=0
# 2025-04-21 10:15:46,198 - INFO - (scenario_24) Iter 50/250: OF=23.1939, TMT=-7.1317, MaxNegMT=-0.2613, Errors=0
# 2025-04-21 10:15:46,377 - INFO - (scenario_24) Iter 75/250: OF=30.4030, TMT=-5.7206, MaxNegMT=-0.3358, Errors=0
# 2025-04-21 10:15:46,456 - INFO - (scenario_24) Iter 100/250: OF=26.1477, TMT=-3.6006, MaxNegMT=-0.4995, Errors=0
# 2025-04-21 10:15:46,487 - INFO - (scenario_24) Iter 125/250: OF=35.8676, TMT=-4.5003, MaxNegMT=-0.6236, Errors=0
# 2025-04-21 10:15:46,583 - INFO - (scenario_24) Iter 150/250: OF=29.4328, TMT=-3.3837, MaxNegMT=-0.4472, Errors=0
# 2025-04-21 10:15:46,626 - INFO - (scenario_24) Iter 175/250: OF=32.1814, TMT=-3.2239, MaxNegMT=-0.6600, Errors=0
# 2025-04-21 10:15:46,656 - INFO - (scenario_24) Iter 200/250: OF=20.5059, TMT=-0.6137, MaxNegMT=-0.1107, Errors=0
# 2025-04-21 10:15:46,666 - INFO - (scenario_24) Iter 225/250: OF=21.9407, TMT=-0.8296, MaxNegMT=-0.2840, Errors=0
# 2025-04-21 10:15:46,683 - INFO - (scenario_24) Iter 250/250: OF=20.3827, TMT=-0.2851, MaxNegMT=-0.1425, Errors=0
# 2025-04-21 10:15:46,683 - WARNING - (scenario_24) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:46,684 - WARNING - (scenario_24) Estado final: TMT=-0.2851, MaxNegMT=-0.1425, Errors=0
# 2025-04-21 10:15:46,688 - INFO - --- Optimización finalizada para scenario_24 ---
# 2025-04-21 10:15:46,690 - INFO - --- Iniciando optimización para scenario_25 ---
# 2025-04-21 10:15:46,694 - INFO - (scenario_25) Iter 1/250: OF=50.6114, TMT=-17.6327, MaxNegMT=-0.2499, Errors=0
# 2025-04-21 10:15:46,720 - INFO - (scenario_25) Iter 25/250: OF=47.3713, TMT=-11.3811, MaxNegMT=-0.5174, Errors=0
# 2025-04-21 10:15:46,743 - INFO - (scenario_25) Iter 50/250: OF=24.8884, TMT=-7.3018, MaxNegMT=-0.3238, Errors=0
# 2025-04-21 10:15:46,766 - INFO - (scenario_25) Iter 75/250: OF=29.3144, TMT=-5.8006, MaxNegMT=-0.3245, Errors=0
# 2025-04-21 10:15:46,908 - INFO - (scenario_25) Iter 100/250: OF=36.6860, TMT=-5.3494, MaxNegMT=-0.4474, Errors=0
# 2025-04-21 10:15:46,955 - INFO - (scenario_25) Iter 125/250: OF=29.3394, TMT=-3.8716, MaxNegMT=-0.3571, Errors=0
# 2025-04-21 10:15:47,002 - INFO - (scenario_25) Iter 150/250: OF=30.2603, TMT=-2.8216, MaxNegMT=-0.5856, Errors=0
# 2025-04-21 10:15:47,026 - INFO - (scenario_25) Iter 175/250: OF=25.6059, TMT=-2.3063, MaxNegMT=-0.2994, Errors=0
# 2025-04-21 10:15:47,035 - INFO - (scenario_25) Iter 200/250: OF=22.0486, TMT=-0.9338, MaxNegMT=-0.3175, Errors=0
# 2025-04-21 10:15:47,053 - INFO - (scenario_25) Iter 225/250: OF=19.7421, TMT=-0.2344, MaxNegMT=-0.0480, Errors=0
# 2025-04-21 10:15:47,069 - INFO - (scenario_25) Iter 250/250: OF=19.7216, TMT=-0.1597, MaxNegMT=-0.0687, Errors=0
# 2025-04-21 10:15:47,070 - WARNING - (scenario_25) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:47,071 - WARNING - (scenario_25) Estado final: TMT=-0.1597, MaxNegMT=-0.0687, Errors=0
# 2025-04-21 10:15:47,074 - INFO - --- Optimización finalizada para scenario_25 ---
# 2025-04-21 10:15:47,076 - INFO - --- Iniciando optimización para scenario_26 ---
# 2025-04-21 10:15:47,080 - INFO - (scenario_26) Iter 1/250: OF=50.6934, TMT=-17.7518, MaxNegMT=-0.2400, Errors=0
# 2025-04-21 10:15:47,117 - INFO - (scenario_26) Iter 25/250: OF=46.7214, TMT=-11.3901, MaxNegMT=-0.5772, Errors=0
# 2025-04-21 10:15:47,132 - INFO - (scenario_26) Iter 50/250: OF=23.9881, TMT=-7.7519, MaxNegMT=-0.2427, Errors=0
# 2025-04-21 10:15:47,221 - INFO - (scenario_26) Iter 75/250: OF=23.3208, TMT=-4.7969, MaxNegMT=-0.2496, Errors=0
# 2025-04-21 10:15:47,274 - INFO - (scenario_26) Iter 100/250: OF=31.0877, TMT=-4.6004, MaxNegMT=-0.3922, Errors=0
# 2025-04-21 10:15:47,303 - INFO - (scenario_26) Iter 125/250: OF=25.2319, TMT=-2.8692, MaxNegMT=-0.4026, Errors=0
# 2025-04-21 10:15:47,369 - INFO - (scenario_26) Iter 150/250: OF=32.0905, TMT=-3.5142, MaxNegMT=-0.6469, Errors=0
# 2025-04-21 10:15:47,392 - INFO - (scenario_26) Iter 175/250: OF=25.5099, TMT=-2.6971, MaxNegMT=-0.2783, Errors=0
# 2025-04-21 10:15:47,404 - INFO - (scenario_26) Iter 200/250: OF=20.7627, TMT=-1.0008, MaxNegMT=-0.1664, Errors=0
# 2025-04-21 10:15:47,426 - INFO - (scenario_26) Iter 225/250: OF=20.0540, TMT=-0.7105, MaxNegMT=-0.1297, Errors=0
# 2025-04-21 10:15:47,440 - INFO - (scenario_26) Iter 250/250: OF=20.2509, TMT=-0.8632, MaxNegMT=-0.1455, Errors=0
# 2025-04-21 10:15:47,442 - WARNING - (scenario_26) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:47,445 - WARNING - (scenario_26) Estado final: TMT=-0.8632, MaxNegMT=-0.1455, Errors=0
# 2025-04-21 10:15:47,449 - INFO - --- Optimización finalizada para scenario_26 ---
# 2025-04-21 10:15:47,453 - INFO - --- Iniciando optimización para scenario_27 ---
# 2025-04-21 10:15:47,456 - INFO - (scenario_27) Iter 1/250: OF=50.6214, TMT=-17.8324, MaxNegMT=-0.2236, Errors=0
# 2025-04-21 10:15:47,492 - INFO - (scenario_27) Iter 25/250: OF=46.6318, TMT=-11.1876, MaxNegMT=-0.6092, Errors=0
# 2025-04-21 10:15:47,509 - INFO - (scenario_27) Iter 50/250: OF=24.7727, TMT=-7.9273, MaxNegMT=-0.2589, Errors=0
# 2025-04-21 10:15:47,553 - INFO - (scenario_27) Iter 75/250: OF=29.6949, TMT=-6.1994, MaxNegMT=-0.3211, Errors=0
# 2025-04-21 10:15:47,681 - INFO - (scenario_27) Iter 100/250: OF=27.0848, TMT=-3.9087, MaxNegMT=-0.3718, Errors=0
# 2025-04-21 10:15:47,698 - INFO - (scenario_27) Iter 125/250: OF=29.7107, TMT=-3.8159, MaxNegMT=-0.4175, Errors=0
# 2025-04-21 10:15:47,745 - INFO - (scenario_27) Iter 150/250: OF=29.3429, TMT=-2.8348, MaxNegMT=-0.5942, Errors=0
# 2025-04-21 10:15:47,771 - INFO - (scenario_27) Iter 175/250: OF=20.4286, TMT=-1.0870, MaxNegMT=-0.1498, Errors=0
# 2025-04-21 10:15:47,790 - INFO - (scenario_27) Iter 200/250: OF=20.3931, TMT=-1.0236, MaxNegMT=-0.1498, Errors=0
# 2025-04-21 10:15:47,811 - INFO - (scenario_27) Iter 225/250: OF=20.3631, TMT=-1.0448, MaxNegMT=-0.1498, Errors=0
# 2025-04-21 10:15:47,832 - INFO - (scenario_27) Iter 250/250: OF=20.4185, TMT=-1.0482, MaxNegMT=-0.1498, Errors=0
# 2025-04-21 10:15:47,833 - WARNING - (scenario_27) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:47,839 - WARNING - (scenario_27) Estado final: TMT=-1.0482, MaxNegMT=-0.1498, Errors=0
# 2025-04-21 10:15:47,841 - INFO - --- Optimización finalizada para scenario_27 ---
# 2025-04-21 10:15:47,842 - INFO - --- Iniciando optimización para scenario_28 ---
# 2025-04-21 10:15:47,842 - INFO - (scenario_28) Iter 1/250: OF=50.5612, TMT=-17.8340, MaxNegMT=-0.2166, Errors=0
# 2025-04-21 10:15:47,876 - INFO - (scenario_28) Iter 25/250: OF=45.8465, TMT=-11.3095, MaxNegMT=-0.5571, Errors=0
# 2025-04-21 10:15:47,897 - INFO - (scenario_28) Iter 50/250: OF=24.8912, TMT=-7.6753, MaxNegMT=-0.2615, Errors=0
# 2025-04-21 10:15:47,919 - INFO - (scenario_28) Iter 75/250: OF=26.7354, TMT=-5.6701, MaxNegMT=-0.2982, Errors=0
# 2025-04-21 10:15:48,043 - INFO - (scenario_28) Iter 100/250: OF=33.3374, TMT=-4.7438, MaxNegMT=-0.5376, Errors=0
# 2025-04-21 10:15:48,076 - INFO - (scenario_28) Iter 125/250: OF=26.4576, TMT=-3.7177, MaxNegMT=-0.3190, Errors=0
# 2025-04-21 10:15:48,139 - INFO - (scenario_28) Iter 150/250: OF=26.7305, TMT=-2.8244, MaxNegMT=-0.3157, Errors=0
# 2025-04-21 10:15:48,165 - INFO - (scenario_28) Iter 175/250: OF=20.7645, TMT=-0.7510, MaxNegMT=-0.2680, Errors=0
# 2025-04-21 10:15:48,187 - INFO - (scenario_28) Iter 200/250: OF=20.1034, TMT=-0.5746, MaxNegMT=-0.1494, Errors=0
# 2025-04-21 10:15:48,204 - INFO - (scenario_28) Iter 225/250: OF=20.0455, TMT=-0.5095, MaxNegMT=-0.1494, Errors=0
# 2025-04-21 10:15:48,218 - INFO - (scenario_28) Iter 250/250: OF=20.0042, TMT=-0.5037, MaxNegMT=-0.1494, Errors=0
# 2025-04-21 10:15:48,223 - WARNING - (scenario_28) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:48,225 - WARNING - (scenario_28) Estado final: TMT=-0.5037, MaxNegMT=-0.1494, Errors=0
# 2025-04-21 10:15:48,229 - INFO - --- Optimización finalizada para scenario_28 ---
# 2025-04-21 10:15:48,237 - INFO - --- Iniciando optimización para scenario_29 ---
# 2025-04-21 10:15:48,241 - INFO - (scenario_29) Iter 1/250: OF=50.6865, TMT=-17.6359, MaxNegMT=-0.2552, Errors=0
# 2025-04-21 10:15:48,277 - INFO - (scenario_29) Iter 25/250: OF=46.5280, TMT=-11.1393, MaxNegMT=-0.5793, Errors=0
# 2025-04-21 10:15:48,319 - INFO - (scenario_29) Iter 50/250: OF=23.7614, TMT=-7.3394, MaxNegMT=-0.2626, Errors=0
# 2025-04-21 10:15:48,420 - INFO - (scenario_29) Iter 75/250: OF=25.8086, TMT=-4.9349, MaxNegMT=-0.3385, Errors=0
# 2025-04-21 10:15:48,486 - INFO - (scenario_29) Iter 100/250: OF=24.3161, TMT=-3.3763, MaxNegMT=-0.3255, Errors=0
# 2025-04-21 10:15:48,553 - INFO - (scenario_29) Iter 125/250: OF=26.2038, TMT=-2.9463, MaxNegMT=-0.3190, Errors=0
# 2025-04-21 10:15:48,564 - INFO - (scenario_29) Iter 150/250: OF=41.3775, TMT=-3.9999, MaxNegMT=-0.8566, Errors=0
# 2025-04-21 10:15:48,603 - INFO - (scenario_29) Iter 175/250: OF=23.0713, TMT=-1.8758, MaxNegMT=-0.3080, Errors=0
# 2025-04-21 10:15:48,628 - INFO - (scenario_29) Iter 200/250: OF=30.1191, TMT=-2.9079, MaxNegMT=-0.5400, Errors=0
# 2025-04-21 10:15:48,647 - INFO - (scenario_29) Iter 225/250: OF=22.3391, TMT=-1.2145, MaxNegMT=-0.2721, Errors=0
# 2025-04-21 10:15:48,666 - INFO - (scenario_29) Iter 250/250: OF=20.0054, TMT=-0.6238, MaxNegMT=-0.1413, Errors=0
# 2025-04-21 10:15:48,668 - WARNING - (scenario_29) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:48,670 - WARNING - (scenario_29) Estado final: TMT=-0.6238, MaxNegMT=-0.1413, Errors=0
# 2025-04-21 10:15:48,672 - INFO - --- Optimización finalizada para scenario_29 ---
# 2025-04-21 10:15:48,676 - INFO - --- Iniciando optimización para scenario_30 ---
# 2025-04-21 10:15:48,683 - INFO - (scenario_30) Iter 1/250: OF=50.6698, TMT=-17.6369, MaxNegMT=-0.2518, Errors=0
# 2025-04-21 10:15:48,724 - INFO - (scenario_30) Iter 25/250: OF=47.5477, TMT=-11.2004, MaxNegMT=-0.5827, Errors=0
# 2025-04-21 10:15:48,750 - INFO - (scenario_30) Iter 50/250: OF=24.0088, TMT=-7.0898, MaxNegMT=-0.2773, Errors=0
# 2025-04-21 10:15:48,773 - INFO - (scenario_30) Iter 75/250: OF=30.5884, TMT=-6.0476, MaxNegMT=-0.3475, Errors=0
# 2025-04-21 10:15:48,998 - INFO - (scenario_30) Iter 100/250: OF=35.9364, TMT=-5.0273, MaxNegMT=-0.5503, Errors=0
# 2025-04-21 10:15:49,047 - INFO - (scenario_30) Iter 125/250: OF=28.7553, TMT=-3.5213, MaxNegMT=-0.4509, Errors=0
# 2025-04-21 10:15:49,058 - INFO - (scenario_30) Iter 150/250: OF=29.6419, TMT=-2.8516, MaxNegMT=-0.4092, Errors=0
# 2025-04-21 10:15:49,081 - INFO - (scenario_30) Iter 175/250: OF=24.8889, TMT=-1.9300, MaxNegMT=-0.2632, Errors=0
# 2025-04-21 10:15:49,095 - INFO - (scenario_30) Iter 200/250: OF=19.7968, TMT=-0.3693, MaxNegMT=-0.0855, Errors=0
# 2025-04-21 10:15:49,113 - INFO - (scenario_30) Iter 225/250: OF=19.6122, TMT=-0.2822, MaxNegMT=-0.0920, Errors=0
# 2025-04-21 10:15:49,129 - INFO - (scenario_30) Iter 250/250: OF=19.6808, TMT=-0.2970, MaxNegMT=-0.1079, Errors=0
# 2025-04-21 10:15:49,130 - WARNING - (scenario_30) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:49,132 - WARNING - (scenario_30) Estado final: TMT=-0.2970, MaxNegMT=-0.1079, Errors=0
# 2025-04-21 10:15:49,135 - INFO - --- Optimización finalizada para scenario_30 ---
# 2025-04-21 10:15:49,136 - INFO - --- Iniciando optimización para scenario_31 ---
# 2025-04-21 10:15:49,137 - INFO - (scenario_31) Iter 1/250: OF=50.7019, TMT=-17.7275, MaxNegMT=-0.2444, Errors=0
# 2025-04-21 10:15:49,179 - INFO - (scenario_31) Iter 25/250: OF=47.6672, TMT=-11.1827, MaxNegMT=-0.6032, Errors=0
# 2025-04-21 10:15:49,199 - INFO - (scenario_31) Iter 50/250: OF=24.0661, TMT=-7.5171, MaxNegMT=-0.2701, Errors=0
# 2025-04-21 10:15:49,216 - INFO - (scenario_31) Iter 75/250: OF=27.0537, TMT=-5.3259, MaxNegMT=-0.3342, Errors=0
# 2025-04-21 10:15:49,311 - INFO - (scenario_31) Iter 100/250: OF=36.5196, TMT=-5.1175, MaxNegMT=-0.5404, Errors=0
# 2025-04-21 10:15:49,334 - INFO - (scenario_31) Iter 125/250: OF=24.9992, TMT=-3.2103, MaxNegMT=-0.3190, Errors=0
# 2025-04-21 10:15:49,360 - INFO - (scenario_31) Iter 150/250: OF=24.6722, TMT=-2.4252, MaxNegMT=-0.3349, Errors=0
# 2025-04-21 10:15:49,376 - INFO - (scenario_31) Iter 175/250: OF=23.6812, TMT=-2.1099, MaxNegMT=-0.2723, Errors=0
# 2025-04-21 10:15:49,397 - INFO - (scenario_31) Iter 200/250: OF=19.7055, TMT=-0.7538, MaxNegMT=-0.1325, Errors=0
# 2025-04-21 10:15:49,425 - INFO - (scenario_31) Iter 225/250: OF=20.3262, TMT=-0.9204, MaxNegMT=-0.1989, Errors=0
# 2025-04-21 10:15:49,435 - INFO - (scenario_31) Iter 250/250: OF=19.6372, TMT=-0.6375, MaxNegMT=-0.1231, Errors=0
# 2025-04-21 10:15:49,436 - WARNING - (scenario_31) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:49,437 - WARNING - (scenario_31) Estado final: TMT=-0.6375, MaxNegMT=-0.1231, Errors=0
# 2025-04-21 10:15:49,442 - INFO - --- Optimización finalizada para scenario_31 ---
# 2025-04-21 10:15:49,445 - INFO - --- Iniciando optimización para scenario_32 ---
# 2025-04-21 10:15:49,448 - INFO - (scenario_32) Iter 1/250: OF=50.6953, TMT=-17.7295, MaxNegMT=-0.2433, Errors=0
# 2025-04-21 10:15:49,492 - INFO - (scenario_32) Iter 25/250: OF=47.7489, TMT=-11.2324, MaxNegMT=-0.5931, Errors=0
# 2025-04-21 10:15:49,532 - INFO - (scenario_32) Iter 50/250: OF=25.2776, TMT=-7.8962, MaxNegMT=-0.2554, Errors=0
# 2025-04-21 10:15:49,741 - INFO - (scenario_32) Iter 75/250: OF=30.5541, TMT=-5.9733, MaxNegMT=-0.3225, Errors=0
# 2025-04-21 10:15:49,786 - INFO - (scenario_32) Iter 100/250: OF=28.0013, TMT=-3.9246, MaxNegMT=-0.3814, Errors=0
# 2025-04-21 10:15:49,807 - INFO - (scenario_32) Iter 125/250: OF=30.6866, TMT=-4.3787, MaxNegMT=-0.3189, Errors=0
# 2025-04-21 10:15:49,831 - INFO - (scenario_32) Iter 150/250: OF=26.6398, TMT=-2.6755, MaxNegMT=-0.3674, Errors=0
# 2025-04-21 10:15:49,850 - INFO - (scenario_32) Iter 175/250: OF=21.6866, TMT=-1.4522, MaxNegMT=-0.2793, Errors=0
# 2025-04-21 10:15:49,864 - INFO - (scenario_32) Iter 200/250: OF=27.4338, TMT=-2.8300, MaxNegMT=-0.2885, Errors=0
# 2025-04-21 10:15:49,882 - INFO - (scenario_32) Iter 225/250: OF=20.4526, TMT=-0.6319, MaxNegMT=-0.1476, Errors=0
# 2025-04-21 10:15:49,901 - INFO - (scenario_32) Iter 250/250: OF=20.5552, TMT=-0.6906, MaxNegMT=-0.1476, Errors=0
# 2025-04-21 10:15:49,902 - WARNING - (scenario_32) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:49,904 - WARNING - (scenario_32) Estado final: TMT=-0.6906, MaxNegMT=-0.1476, Errors=0
# 2025-04-21 10:15:49,908 - INFO - --- Optimización finalizada para scenario_32 ---
# 2025-04-21 10:15:49,909 - INFO - --- Iniciando optimización para scenario_33 ---
# 2025-04-21 10:15:49,912 - INFO - (scenario_33) Iter 1/250: OF=50.3256, TMT=-17.6542, MaxNegMT=-0.2367, Errors=0
# 2025-04-21 10:15:49,960 - INFO - (scenario_33) Iter 25/250: OF=43.8115, TMT=-10.9545, MaxNegMT=-0.4970, Errors=0
# 2025-04-21 10:15:49,974 - INFO - (scenario_33) Iter 50/250: OF=23.7814, TMT=-7.0870, MaxNegMT=-0.2703, Errors=0
# 2025-04-21 10:15:50,021 - INFO - (scenario_33) Iter 75/250: OF=27.3456, TMT=-5.2660, MaxNegMT=-0.3713, Errors=0
# 2025-04-21 10:15:50,100 - INFO - (scenario_33) Iter 100/250: OF=26.2743, TMT=-3.3074, MaxNegMT=-0.3875, Errors=0
# 2025-04-21 10:15:50,133 - INFO - (scenario_33) Iter 125/250: OF=31.3137, TMT=-3.5549, MaxNegMT=-0.6061, Errors=0
# 2025-04-21 10:15:50,159 - INFO - (scenario_33) Iter 150/250: OF=29.2016, TMT=-2.9966, MaxNegMT=-0.4611, Errors=0
# 2025-04-21 10:15:50,168 - INFO - (scenario_33) Iter 175/250: OF=22.0619, TMT=-1.4536, MaxNegMT=-0.2077, Errors=0
# 2025-04-21 10:15:50,192 - INFO - (scenario_33) Iter 200/250: OF=24.5645, TMT=-1.8831, MaxNegMT=-0.3457, Errors=0
# 2025-04-21 10:15:50,200 - INFO - (scenario_33) Iter 225/250: OF=21.0461, TMT=-0.8180, MaxNegMT=-0.1465, Errors=0
# 2025-04-21 10:15:50,215 - INFO - (scenario_33) Iter 250/250: OF=20.9109, TMT=-0.7879, MaxNegMT=-0.1333, Errors=0
# 2025-04-21 10:15:50,216 - WARNING - (scenario_33) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:50,216 - WARNING - (scenario_33) Estado final: TMT=-0.7879, MaxNegMT=-0.1333, Errors=0
# 2025-04-21 10:15:50,217 - INFO - --- Optimización finalizada para scenario_33 ---
# 2025-04-21 10:15:50,217 - INFO - --- Iniciando optimización para scenario_34 ---
# 2025-04-21 10:15:50,217 - INFO - (scenario_34) Iter 1/250: OF=50.4531, TMT=-17.7346, MaxNegMT=-0.2247, Errors=0
# 2025-04-21 10:15:50,303 - INFO - (scenario_34) Iter 25/250: OF=43.8954, TMT=-11.0966, MaxNegMT=-0.5455, Errors=0
# 2025-04-21 10:15:50,347 - INFO - (scenario_34) Iter 50/250: OF=22.4705, TMT=-7.1438, MaxNegMT=-0.2289, Errors=0
# 2025-04-21 10:15:50,452 - INFO - (scenario_34) Iter 75/250: OF=30.6371, TMT=-5.7110, MaxNegMT=-0.3192, Errors=0
# 2025-04-21 10:15:50,512 - INFO - (scenario_34) Iter 100/250: OF=24.4225, TMT=-3.1272, MaxNegMT=-0.3132, Errors=0
# 2025-04-21 10:15:50,521 - INFO - (scenario_34) Iter 125/250: OF=24.1555, TMT=-2.5649, MaxNegMT=-0.3187, Errors=0
# 2025-04-21 10:15:50,545 - INFO - (scenario_34) Iter 150/250: OF=36.8559, TMT=-4.5064, MaxNegMT=-0.7152, Errors=0
# 2025-04-21 10:15:50,565 - INFO - (scenario_34) Iter 175/250: OF=28.8791, TMT=-2.8165, MaxNegMT=-0.4885, Errors=0
# 2025-04-21 10:15:50,592 - INFO - (scenario_34) Iter 200/250: OF=35.8087, TMT=-3.2698, MaxNegMT=-0.5928, Errors=0
# 2025-04-21 10:15:50,601 - INFO - (scenario_34) Iter 225/250: OF=20.9394, TMT=-0.2564, MaxNegMT=-0.1229, Errors=0
# 2025-04-21 10:15:50,615 - INFO - (scenario_34) Iter 250/250: OF=20.8576, TMT=-0.1963, MaxNegMT=-0.1066, Errors=0
# 2025-04-21 10:15:50,616 - WARNING - (scenario_34) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:50,616 - WARNING - (scenario_34) Estado final: TMT=-0.1963, MaxNegMT=-0.1066, Errors=0
# 2025-04-21 10:15:50,619 - INFO - --- Optimización finalizada para scenario_34 ---
# 2025-04-21 10:15:50,622 - INFO - --- Iniciando optimización para scenario_35 ---
# 2025-04-21 10:15:50,624 - INFO - (scenario_35) Iter 1/250: OF=50.3129, TMT=-17.6591, MaxNegMT=-0.2351, Errors=0
# 2025-04-21 10:15:50,658 - INFO - (scenario_35) Iter 25/250: OF=42.5293, TMT=-11.0628, MaxNegMT=-0.5201, Errors=0
# 2025-04-21 10:15:50,697 - INFO - (scenario_35) Iter 50/250: OF=23.2881, TMT=-6.9881, MaxNegMT=-0.2343, Errors=0
# 2025-04-21 10:15:50,804 - INFO - (scenario_35) Iter 75/250: OF=32.6364, TMT=-6.4389, MaxNegMT=-0.3256, Errors=0
# 2025-04-21 10:15:50,821 - INFO - (scenario_35) Iter 100/250: OF=24.8418, TMT=-3.1095, MaxNegMT=-0.3136, Errors=0
# 2025-04-21 10:15:50,857 - INFO - (scenario_35) Iter 125/250: OF=27.3233, TMT=-3.0058, MaxNegMT=-0.3876, Errors=0
# 2025-04-21 10:15:50,876 - INFO - (scenario_35) Iter 150/250: OF=20.0459, TMT=-1.3037, MaxNegMT=-0.1495, Errors=0
# 2025-04-21 10:15:50,897 - INFO - (scenario_35) Iter 175/250: OF=28.9286, TMT=-2.9308, MaxNegMT=-0.5100, Errors=0
# 2025-04-21 10:15:50,908 - INFO - (scenario_35) Iter 200/250: OF=28.7580, TMT=-2.8043, MaxNegMT=-0.4111, Errors=0
# 2025-04-21 10:15:50,927 - INFO - (scenario_35) Iter 225/250: OF=25.6933, TMT=-1.6413, MaxNegMT=-0.2918, Errors=0
# 2025-04-21 10:15:50,939 - INFO - (scenario_35) Iter 250/250: OF=20.3053, TMT=-0.2800, MaxNegMT=-0.0868, Errors=0
# 2025-04-21 10:15:50,940 - WARNING - (scenario_35) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:15:50,940 - WARNING - (scenario_35) Estado final: TMT=-0.2800, MaxNegMT=-0.0868, Errors=0
# 2025-04-21 10:15:50,941 - INFO - --- Optimización finalizada para scenario_35 ---
# 2025-04-21 10:15:50,943 - INFO - --- Iniciando optimización para scenario_36 ---
# ...
# 2025-04-21 10:16:00,425 - INFO - (scenario_59) Iter 200/250: OF=19.6915, TMT=-1.1894, MaxNegMT=-0.1389, Errors=0
# 2025-04-21 10:16:00,435 - INFO - (scenario_59) Iter 225/250: OF=19.6507, TMT=-1.2506, MaxNegMT=-0.1301, Errors=0
# 2025-04-21 10:16:00,459 - INFO - (scenario_59) Iter 250/250: OF=19.5712, TMT=-1.2197, MaxNegMT=-0.1301, Errors=0
# 2025-04-21 10:16:00,460 - WARNING - (scenario_59) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:00,462 - WARNING - (scenario_59) Estado final: TMT=-1.2197, MaxNegMT=-0.1301, Errors=0
# 2025-04-21 10:16:00,468 - INFO - --- Optimización finalizada para scenario_59 ---
# 2025-04-21 10:16:00,470 - INFO - --- Iniciando optimización para scenario_60 ---
# 2025-04-21 10:16:00,473 - INFO - (scenario_60) Iter 1/250: OF=49.5989, TMT=-17.3760, MaxNegMT=-0.2421, Errors=0
# 2025-04-21 10:16:00,505 - INFO - (scenario_60) Iter 25/250: OF=42.8122, TMT=-10.2928, MaxNegMT=-0.4452, Errors=0
# 2025-04-21 10:16:00,520 - INFO - (scenario_60) Iter 50/250: OF=20.8251, TMT=-6.1221, MaxNegMT=-0.2597, Errors=0
# 2025-04-21 10:16:00,658 - INFO - (scenario_60) Iter 75/250: OF=25.5100, TMT=-4.8410, MaxNegMT=-0.3501, Errors=0
# 2025-04-21 10:16:00,703 - INFO - (scenario_60) Iter 100/250: OF=28.6292, TMT=-3.5980, MaxNegMT=-0.3485, Errors=0
# 2025-04-21 10:16:00,787 - INFO - (scenario_60) Iter 125/250: OF=28.2031, TMT=-3.0485, MaxNegMT=-0.3928, Errors=0
# 2025-04-21 10:16:00,799 - INFO - (scenario_60) Iter 150/250: OF=22.3931, TMT=-1.4081, MaxNegMT=-0.3081, Errors=0
# 2025-04-21 10:16:00,869 - INFO - (scenario_60) Iter 175/250: OF=24.2520, TMT=-1.6652, MaxNegMT=-0.2774, Errors=0
# 2025-04-21 10:16:00,946 - INFO - (scenario_60) Iter 200/250: OF=23.0321, TMT=-1.3548, MaxNegMT=-0.2888, Errors=0
# 2025-04-21 10:16:00,989 - INFO - (scenario_60) Iter 225/250: OF=20.1623, TMT=-0.3428, MaxNegMT=-0.1066, Errors=0
# 2025-04-21 10:16:01,002 - INFO - (scenario_60) Iter 250/250: OF=19.9084, TMT=-0.2750, MaxNegMT=-0.0841, Errors=0
# 2025-04-21 10:16:01,002 - WARNING - (scenario_60) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:01,002 - WARNING - (scenario_60) Estado final: TMT=-0.2750, MaxNegMT=-0.0841, Errors=0
# 2025-04-21 10:16:01,006 - INFO - --- Optimización finalizada para scenario_60 ---
# 2025-04-21 10:16:01,008 - INFO - --- Iniciando optimización para scenario_61 ---
# 2025-04-21 10:16:01,010 - INFO - (scenario_61) Iter 1/250: OF=50.1897, TMT=-17.5622, MaxNegMT=-0.2413, Errors=0
# 2025-04-21 10:16:01,045 - INFO - (scenario_61) Iter 25/250: OF=43.9719, TMT=-10.7722, MaxNegMT=-0.5167, Errors=0
# 2025-04-21 10:16:01,065 - INFO - (scenario_61) Iter 50/250: OF=22.9698, TMT=-6.5986, MaxNegMT=-0.3028, Errors=0
# 2025-04-21 10:16:01,083 - INFO - (scenario_61) Iter 75/250: OF=27.4467, TMT=-5.0029, MaxNegMT=-0.3101, Errors=0
# 2025-04-21 10:16:01,104 - INFO - (scenario_61) Iter 100/250: OF=24.9601, TMT=-2.8716, MaxNegMT=-0.3767, Errors=0
# 2025-04-21 10:16:01,119 - INFO - (scenario_61) Iter 125/250: OF=20.2730, TMT=-1.6691, MaxNegMT=-0.2182, Errors=0
# 2025-04-21 10:16:01,135 - INFO - (scenario_61) Iter 150/250: OF=26.6548, TMT=-2.3662, MaxNegMT=-0.5483, Errors=0
# 2025-04-21 10:16:01,296 - INFO - (scenario_61) Iter 175/250: OF=23.7491, TMT=-1.6686, MaxNegMT=-0.3702, Errors=0
# 2025-04-21 10:16:01,345 - INFO - (scenario_61) Iter 200/250: OF=19.6047, TMT=-0.7013, MaxNegMT=-0.1490, Errors=0
# 2025-04-21 10:16:01,427 - INFO - (scenario_61) Iter 225/250: OF=19.3633, TMT=-0.6911, MaxNegMT=-0.1266, Errors=0
# 2025-04-21 10:16:01,449 - INFO - (scenario_61) Iter 250/250: OF=19.3194, TMT=-0.6028, MaxNegMT=-0.1353, Errors=0
# 2025-04-21 10:16:01,452 - WARNING - (scenario_61) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:01,454 - WARNING - (scenario_61) Estado final: TMT=-0.6028, MaxNegMT=-0.1353, Errors=0
# 2025-04-21 10:16:01,458 - INFO - --- Optimización finalizada para scenario_61 ---
# 2025-04-21 10:16:01,461 - INFO - --- Iniciando optimización para scenario_62 ---
# 2025-04-21 10:16:01,464 - INFO - (scenario_62) Iter 1/250: OF=50.0078, TMT=-17.4904, MaxNegMT=-0.2389, Errors=0
# 2025-04-21 10:16:01,596 - INFO - (scenario_62) Iter 25/250: OF=43.3089, TMT=-10.6561, MaxNegMT=-0.5016, Errors=0
# 2025-04-21 10:16:01,610 - INFO - (scenario_62) Iter 50/250: OF=21.8274, TMT=-6.3567, MaxNegMT=-0.2585, Errors=0
# 2025-04-21 10:16:01,635 - INFO - (scenario_62) Iter 75/250: OF=27.8198, TMT=-4.8631, MaxNegMT=-0.4288, Errors=0
# 2025-04-21 10:16:01,654 - INFO - (scenario_62) Iter 100/250: OF=20.3983, TMT=-2.1717, MaxNegMT=-0.2538, Errors=0
# 2025-04-21 10:16:01,667 - INFO - (scenario_62) Iter 125/250: OF=24.4905, TMT=-2.4246, MaxNegMT=-0.4338, Errors=0
# 2025-04-21 10:16:01,676 - INFO - (scenario_62) Iter 150/250: OF=26.7407, TMT=-2.3125, MaxNegMT=-0.5466, Errors=0
# 2025-04-21 10:16:01,813 - INFO - (scenario_62) Iter 175/250: OF=24.2365, TMT=-2.0473, MaxNegMT=-0.2953, Errors=0
# 2025-04-21 10:16:01,896 - INFO - (scenario_62) Iter 200/250: OF=19.1398, TMT=-0.5453, MaxNegMT=-0.1480, Errors=0
# 2025-04-21 10:16:01,944 - INFO - (scenario_62) Iter 225/250: OF=19.1437, TMT=-0.5134, MaxNegMT=-0.1480, Errors=0
# 2025-04-21 10:16:01,980 - INFO - (scenario_62) Iter 250/250: OF=19.0079, TMT=-0.4111, MaxNegMT=-0.1480, Errors=0
# 2025-04-21 10:16:01,984 - WARNING - (scenario_62) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:01,990 - WARNING - (scenario_62) Estado final: TMT=-0.4111, MaxNegMT=-0.1480, Errors=0
# 2025-04-21 10:16:02,000 - INFO - --- Optimización finalizada para scenario_62 ---
# 2025-04-21 10:16:02,001 - INFO - --- Iniciando optimización para scenario_63 ---
# 2025-04-21 10:16:02,003 - INFO - (scenario_63) Iter 1/250: OF=50.1843, TMT=-17.5730, MaxNegMT=-0.2357, Errors=0
# 2025-04-21 10:16:02,047 - INFO - (scenario_63) Iter 25/250: OF=44.0425, TMT=-10.5762, MaxNegMT=-0.5549, Errors=0
# 2025-04-21 10:16:02,074 - INFO - (scenario_63) Iter 50/250: OF=21.5581, TMT=-6.4948, MaxNegMT=-0.2390, Errors=0
# 2025-04-21 10:16:02,100 - INFO - (scenario_63) Iter 75/250: OF=27.2704, TMT=-5.4116, MaxNegMT=-0.2952, Errors=0
# 2025-04-21 10:16:02,118 - INFO - (scenario_63) Iter 100/250: OF=22.2952, TMT=-2.5006, MaxNegMT=-0.3545, Errors=0
# 2025-04-21 10:16:02,138 - INFO - (scenario_63) Iter 125/250: OF=29.3652, TMT=-3.7826, MaxNegMT=-0.3231, Errors=0
# 2025-04-21 10:16:02,189 - INFO - (scenario_63) Iter 150/250: OF=19.3501, TMT=-0.8588, MaxNegMT=-0.1468, Errors=0
# 2025-04-21 10:16:02,353 - INFO - (scenario_63) Iter 175/250: OF=19.4985, TMT=-0.8997, MaxNegMT=-0.1468, Errors=0
# 2025-04-21 10:16:02,382 - INFO - (scenario_63) Iter 200/250: OF=19.4318, TMT=-0.8581, MaxNegMT=-0.1468, Errors=0
# 2025-04-21 10:16:02,460 - INFO - (scenario_63) Iter 225/250: OF=19.3597, TMT=-0.8986, MaxNegMT=-0.1468, Errors=0
# 2025-04-21 10:16:02,477 - INFO - (scenario_63) Iter 250/250: OF=19.2987, TMT=-0.8144, MaxNegMT=-0.1468, Errors=0
# 2025-04-21 10:16:02,480 - WARNING - (scenario_63) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:02,481 - WARNING - (scenario_63) Estado final: TMT=-0.8144, MaxNegMT=-0.1468, Errors=0
# 2025-04-21 10:16:02,487 - INFO - --- Optimización finalizada para scenario_63 ---
# 2025-04-21 10:16:02,489 - INFO - --- Iniciando optimización para scenario_64 ---
# 2025-04-21 10:16:02,496 - INFO - (scenario_64) Iter 1/250: OF=50.0273, TMT=-17.5211, MaxNegMT=-0.2311, Errors=0
# 2025-04-21 10:16:02,538 - INFO - (scenario_64) Iter 25/250: OF=42.3459, TMT=-10.9093, MaxNegMT=-0.4976, Errors=0
# 2025-04-21 10:16:02,568 - INFO - (scenario_64) Iter 50/250: OF=22.0476, TMT=-6.3470, MaxNegMT=-0.2579, Errors=0
# 2025-04-21 10:16:02,597 - INFO - (scenario_64) Iter 75/250: OF=28.0572, TMT=-5.2654, MaxNegMT=-0.3339, Errors=0
# 2025-04-21 10:16:02,621 - INFO - (scenario_64) Iter 100/250: OF=28.9762, TMT=-3.4947, MaxNegMT=-0.5713, Errors=0
# 2025-04-21 10:16:02,636 - INFO - (scenario_64) Iter 125/250: OF=24.5239, TMT=-3.1200, MaxNegMT=-0.2547, Errors=0
# 2025-04-21 10:16:02,772 - INFO - (scenario_64) Iter 150/250: OF=23.2360, TMT=-2.0207, MaxNegMT=-0.3088, Errors=0
# 2025-04-21 10:16:02,814 - INFO - (scenario_64) Iter 175/250: OF=19.4880, TMT=-0.9262, MaxNegMT=-0.1495, Errors=0
# 2025-04-21 10:16:02,824 - INFO - (scenario_64) Iter 200/250: OF=32.0568, TMT=-2.3888, MaxNegMT=-0.7641, Errors=0
# 2025-04-21 10:16:02,837 - INFO - (scenario_64) Iter 225/250: OF=19.2229, TMT=-0.5318, MaxNegMT=-0.1267, Errors=0
# 2025-04-21 10:16:02,898 - INFO - (scenario_64) Iter 250/250: OF=36.8914, TMT=-3.3481, MaxNegMT=-0.5368, Errors=0
# 2025-04-21 10:16:02,898 - WARNING - (scenario_64) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:02,899 - WARNING - (scenario_64) Estado final: TMT=-3.3481, MaxNegMT=-0.5368, Errors=0
# 2025-04-21 10:16:02,900 - INFO - --- Optimización finalizada para scenario_64 ---
# 2025-04-21 10:16:02,902 - INFO - --- Iniciando optimización para scenario_65 ---
# 2025-04-21 10:16:02,904 - INFO - (scenario_65) Iter 1/250: OF=49.2946, TMT=-17.2335, MaxNegMT=-0.2443, Errors=0
# 2025-04-21 10:16:02,943 - INFO - (scenario_65) Iter 25/250: OF=36.9849, TMT=-9.8473, MaxNegMT=-0.4394, Errors=0
# 2025-04-21 10:16:02,964 - INFO - (scenario_65) Iter 50/250: OF=21.6512, TMT=-5.7228, MaxNegMT=-0.2951, Errors=0
# 2025-04-21 10:16:02,989 - INFO - (scenario_65) Iter 75/250: OF=21.1144, TMT=-3.8679, MaxNegMT=-0.2627, Errors=0
# 2025-04-21 10:16:03,006 - INFO - (scenario_65) Iter 100/250: OF=24.2598, TMT=-2.9046, MaxNegMT=-0.3229, Errors=0
# 2025-04-21 10:16:03,089 - INFO - (scenario_65) Iter 125/250: OF=18.3428, TMT=-0.9882, MaxNegMT=-0.1626, Errors=0
# 2025-04-21 10:16:03,125 - INFO - (scenario_65) Iter 150/250: OF=18.2415, TMT=-0.9126, MaxNegMT=-0.1423, Errors=0
# 2025-04-21 10:16:03,175 - INFO - (scenario_65) Iter 175/250: OF=18.3537, TMT=-0.8707, MaxNegMT=-0.1423, Errors=0
# 2025-04-21 10:16:03,184 - INFO - (scenario_65) Iter 200/250: OF=18.2879, TMT=-0.8651, MaxNegMT=-0.1423, Errors=0
# 2025-04-21 10:16:03,198 - INFO - (scenario_65) Iter 225/250: OF=18.1488, TMT=-0.8367, MaxNegMT=-0.1423, Errors=0
# 2025-04-21 10:16:03,222 - INFO - (scenario_65) Iter 250/250: OF=18.2200, TMT=-0.8319, MaxNegMT=-0.1423, Errors=0
# 2025-04-21 10:16:03,223 - WARNING - (scenario_65) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:03,224 - WARNING - (scenario_65) Estado final: TMT=-0.8319, MaxNegMT=-0.1423, Errors=0
# 2025-04-21 10:16:03,225 - INFO - --- Optimización finalizada para scenario_65 ---
# 2025-04-21 10:16:03,225 - INFO - --- Iniciando optimización para scenario_66 ---
# 2025-04-21 10:16:03,229 - INFO - (scenario_66) Iter 1/250: OF=49.4919, TMT=-17.3113, MaxNegMT=-0.2429, Errors=0
# 2025-04-21 10:16:03,257 - INFO - (scenario_66) Iter 25/250: OF=38.8015, TMT=-9.9587, MaxNegMT=-0.4381, Errors=0
# 2025-04-21 10:16:03,272 - INFO - (scenario_66) Iter 50/250: OF=20.7905, TMT=-5.9885, MaxNegMT=-0.2751, Errors=0
# 2025-04-21 10:16:03,295 - INFO - (scenario_66) Iter 75/250: OF=23.4645, TMT=-4.1546, MaxNegMT=-0.2900, Errors=0
# 2025-04-21 10:16:03,427 - INFO - (scenario_66) Iter 100/250: OF=21.1675, TMT=-2.1738, MaxNegMT=-0.3221, Errors=0
# 2025-04-21 10:16:03,463 - INFO - (scenario_66) Iter 125/250: OF=29.9771, TMT=-2.7251, MaxNegMT=-0.6663, Errors=0
# 2025-04-21 10:16:03,487 - INFO - (scenario_66) Iter 150/250: OF=28.8370, TMT=-2.6775, MaxNegMT=-0.6171, Errors=0
# 2025-04-21 10:16:03,499 - INFO - (scenario_66) Iter 175/250: OF=19.9044, TMT=-0.5795, MaxNegMT=-0.2302, Errors=0
# 2025-04-21 10:16:03,514 - INFO - (scenario_66) Iter 200/250: OF=19.0616, TMT=-0.2161, MaxNegMT=-0.1386, Errors=0
# 2025-04-21 10:16:03,536 - INFO - (scenario_66) Iter 225/250: OF=19.0521, TMT=-0.2093, MaxNegMT=-0.1386, Errors=0
# 2025-04-21 10:16:03,551 - INFO - (scenario_66) Iter 250/250: OF=19.0224, TMT=-0.2081, MaxNegMT=-0.1386, Errors=0
# 2025-04-21 10:16:03,551 - WARNING - (scenario_66) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:03,553 - WARNING - (scenario_66) Estado final: TMT=-0.2081, MaxNegMT=-0.1386, Errors=0
# 2025-04-21 10:16:03,556 - INFO - --- Optimización finalizada para scenario_66 ---
# 2025-04-21 10:16:03,560 - INFO - --- Iniciando optimización para scenario_67 ---
# 2025-04-21 10:16:03,566 - INFO - (scenario_67) Iter 1/250: OF=49.3597, TMT=-17.2816, MaxNegMT=-0.2345, Errors=0
# 2025-04-21 10:16:03,603 - INFO - (scenario_67) Iter 25/250: OF=40.6056, TMT=-9.8740, MaxNegMT=-0.4832, Errors=0
# 2025-04-21 10:16:03,629 - INFO - (scenario_67) Iter 50/250: OF=21.1001, TMT=-5.9966, MaxNegMT=-0.2513, Errors=0
# 2025-04-21 10:16:03,669 - INFO - (scenario_67) Iter 75/250: OF=22.4639, TMT=-4.2339, MaxNegMT=-0.2429, Errors=0
# 2025-04-21 10:16:03,728 - INFO - (scenario_67) Iter 100/250: OF=22.8157, TMT=-2.3478, MaxNegMT=-0.3531, Errors=0
# 2025-04-21 10:16:03,778 - INFO - (scenario_67) Iter 125/250: OF=21.9792, TMT=-1.7456, MaxNegMT=-0.3334, Errors=0
# 2025-04-21 10:16:03,813 - INFO - (scenario_67) Iter 150/250: OF=18.6861, TMT=-0.4561, MaxNegMT=-0.1991, Errors=0
# 2025-04-21 10:16:03,948 - INFO - (scenario_67) Iter 175/250: OF=23.6946, TMT=-1.7328, MaxNegMT=-0.2646, Errors=0
# 2025-04-21 10:16:04,049 - INFO - (scenario_67) Iter 200/250: OF=18.9958, TMT=-0.2197, MaxNegMT=-0.1023, Errors=0
# 2025-04-21 10:16:04,070 - INFO - (scenario_67) Iter 225/250: OF=18.9348, TMT=-0.2012, MaxNegMT=-0.1023, Errors=0
# 2025-04-21 10:16:04,097 - INFO - (scenario_67) Iter 250/250: OF=19.0245, TMT=-0.2466, MaxNegMT=-0.0964, Errors=0
# 2025-04-21 10:16:04,100 - WARNING - (scenario_67) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:04,101 - WARNING - (scenario_67) Estado final: TMT=-0.2466, MaxNegMT=-0.0964, Errors=0
# 2025-04-21 10:16:04,111 - INFO - --- Optimización finalizada para scenario_67 ---
# 2025-04-21 10:16:04,113 - INFO - --- Iniciando optimización para scenario_68 ---
# 2025-04-21 10:16:04,118 - INFO - (scenario_68) Iter 1/250: OF=49.5975, TMT=-17.3673, MaxNegMT=-0.2355, Errors=0
# 2025-04-21 10:16:04,189 - INFO - (scenario_68) Iter 25/250: OF=40.3034, TMT=-10.0350, MaxNegMT=-0.4512, Errors=0
# 2025-04-21 10:16:04,217 - INFO - (scenario_68) Iter 50/250: OF=20.1551, TMT=-5.9341, MaxNegMT=-0.2229, Errors=0
# 2025-04-21 10:16:04,237 - INFO - (scenario_68) Iter 75/250: OF=26.0162, TMT=-4.7492, MaxNegMT=-0.2770, Errors=0
# 2025-04-21 10:16:04,255 - INFO - (scenario_68) Iter 100/250: OF=24.4119, TMT=-2.8490, MaxNegMT=-0.3698, Errors=0
# 2025-04-21 10:16:04,346 - INFO - (scenario_68) Iter 125/250: OF=27.1656, TMT=-2.4624, MaxNegMT=-0.4560, Errors=0
# 2025-04-21 10:16:04,482 - INFO - (scenario_68) Iter 150/250: OF=21.3861, TMT=-1.6086, MaxNegMT=-0.2172, Errors=0
# 2025-04-21 10:16:04,507 - INFO - (scenario_68) Iter 175/250: OF=20.7079, TMT=-1.2031, MaxNegMT=-0.2450, Errors=0
# 2025-04-21 10:16:04,631 - INFO - (scenario_68) Iter 200/250: OF=19.8357, TMT=-0.7090, MaxNegMT=-0.1496, Errors=0
# 2025-04-21 10:16:04,654 - INFO - (scenario_68) Iter 225/250: OF=19.7833, TMT=-0.7642, MaxNegMT=-0.1292, Errors=0
# 2025-04-21 10:16:04,683 - INFO - (scenario_68) Iter 250/250: OF=19.9113, TMT=-0.7678, MaxNegMT=-0.1496, Errors=0
# 2025-04-21 10:16:04,691 - WARNING - (scenario_68) La optimización no convergió (o no mejoró) después de 250 iteraciones.
# 2025-04-21 10:16:04,693 - WARNING - (scenario_68) Estado final: TMT=-0.7678, MaxNegMT=-0.1496, Errors=0
# 2025-04-21 10:16:04,696 - INFO - --- Optimización finalizada para scenario_68 ---
# 2025-04-21 10:16:04,727 - INFO - Optimización completada. Escenarios exitosos: 68, Escenarios fallidos/omitidos: 0.
# 2025-04-21 10:16:04,773 - INFO - Formateando resultados optimizados en la estructura de lista deseada...
# 2025-04-21 10:16:04,791 - INFO - Formato de lista creado con 68 escenarios optimizados.
# 2025-04-21 10:16:04,839 - INFO - Archivo con ajustes optimizados (v4, MT>=-0.009, null handling) guardado en: /Users/gustavo/Documents/Projects/TESIS_UNAL/ADAPTIVE_ALGORITHM/data/raw/optimized_relay_values.json
# 2025-04-21 10:16:04,839 - INFO - --- Script de Optimización Finalizado ---
