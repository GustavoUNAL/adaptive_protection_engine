# %% [markdown]
# ## Algoritmo de optimización

# %%
 # -*- coding: utf-8 -*- 
import json
import uuid
import datetime
from collections import OrderedDict, defaultdict
import numpy as np
from scipy.optimize import minimize 
import logging 
import os 

# Configuración básica de logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# --- Parámetros ---
# Ponderaciones de la función objetivo
alpha1, alpha2 = 1.0, 100.0 # Mantener penalización fuerte para coordinación

# Parámetros curva IEC Standard Inverse
k, n   = 0.14, 0.02 

# Intervalo de Tiempo de Coordinación (CTI)
CTI = 0.2 

# Límites para pick_up (Ipi) y TDS
IPI_MIN, IPI_MAX = 0.1, 5.0   
TDS_MIN, TDS_MAX = 0.05, 1.1 
TDS_STEP = 0.01 

# Rutas de entrada/salida (Asegúrate que sean correctas)
INPUT_JSON  = "/Users/gustavo/Documents/Projects/TESIS_UNAL/ADAPTIVE_ALGORITHM/data/processed/independent_relay_pairs.json" 
# Nombre de salida para esta versión
OUTPUT_JSON = "/Users/gustavo/Documents/Projects/TESIS_UNAL/ADAPTIVE_ALGORITHM/data/raw/optimized_relay_values_paper_slsqp_relaxed.json" 

# --- Funciones (timeout, objective_scenario, constraint_delta_t - sin cambios) ---

def timeout(Ishc, Ipi, TDS):
    """Cálculo de timeout bajo curva inversa estándar."""
    if Ipi <= 0: return 1000.0
    ratio = Ishc / Ipi
    if ratio <= 1.0 or TDS <= 0: return 1000.0 
    try: power_term = np.power(ratio, n) 
    except OverflowError: return 1000.0
    if power_term <= 1.0: return 1000.0
    denominator = power_term - 1
    if denominator < 1e-9: return 1000.0 
    time = (k / denominator) * TDS
    MAX_TIMEOUT = 100.0 
    if time < 0 or time > MAX_TIMEOUT or not np.isfinite(time): return MAX_TIMEOUT
    return time

def objective_scenario(x, pairs, relay_idx, alpha1_param, alpha2_param, k_param, n_param, cti_param):
    """Función objetivo: Minimiza tiempos y penaliza descoordinación respecto a CTI."""
    obj_func_val = 0.0; term1_sum = 0.0; term2_sum = 0.0
    calculated_timeouts = {} 
    for p_idx, p in enumerate(pairs): 
        main_relay_name = str(p["main_relay"]["relay"]); backup_relay_name = str(p["backup_relay"]["relay"]) 
        if main_relay_name not in relay_idx or backup_relay_name not in relay_idx: logger.error(f"[Obj] Relé no hallado P{p_idx} M:{main_relay_name} B:{backup_relay_name}"); continue 
        im = relay_idx[main_relay_name]; ib = relay_idx[backup_relay_name]
        if 2*im >= len(x) or 2*ib >= len(x): logger.error(f"[Obj] Índice fuera rango im={im}, ib={ib}, len(x)={len(x)}"); continue
        pu_m, tds_m = x[2*im], x[2*im+1]; pu_b, tds_b = x[2*ib], x[2*ib+1]
        try: mI = float(p["main_relay"]["Ishc"]); bI = float(p["backup_relay"]["Ishc"]) 
        except (ValueError, TypeError, KeyError) as e: logger.error(f"[Obj] Error Ishc P{p_idx} ({main_relay_name}/{backup_relay_name}): {e}"); continue
        key_m = (im, mI); key_b = (ib, bI) 
        if key_m not in calculated_timeouts: calculated_timeouts[key_m] = timeout(mI, pu_m, tds_m)
        t_m = calculated_timeouts[key_m]
        if key_b not in calculated_timeouts: calculated_timeouts[key_b] = timeout(bI, pu_b, tds_b)
        t_b = calculated_timeouts[key_b]
        if not np.isfinite(t_m) or not np.isfinite(t_b): term1 = 1e10; term2 = 1e10; logger.warning(f"[Obj] Tiempo no finito P{p_idx} ({main_relay_name}/{backup_relay_name}) t_m={t_m}, t_b={t_b}.")
        else: term1 = alpha1_param * (t_m**2 + t_b**2); delta_t = t_b - t_m; miscoordination_penalty = max(0, cti_param - delta_t); term2 = alpha2_param * (miscoordination_penalty**2)
        term1_sum += term1; term2_sum += term2; obj_func_val += term1 + term2
    if not np.isfinite(obj_func_val): logger.warning(f"[Obj] OF no finito ({obj_func_val})"); return 1e20 
    return obj_func_val

def constraint_delta_t(x, p, relay_idx, k_param, n_param, cti_param):
    """Constraint function para SLSQP: delta_t = t_b - t_m >= CTI."""
    main_relay_name = str(p["main_relay"]["relay"])
    backup_relay_name = str(p["backup_relay"]["relay"])
    if main_relay_name not in relay_idx or backup_relay_name not in relay_idx: logger.error(f"[Constr] Relé no hallado M:{main_relay_name} B:{backup_relay_name}"); return -1e6 
    im = relay_idx[main_relay_name]; ib = relay_idx[backup_relay_name]
    if 2*im >= len(x) or 2*ib >= len(x): logger.error(f"[Constr] Índice fuera rango im={im}, ib={ib}, len(x)={len(x)}"); return -1e6
    pu_m, tds_m = x[2*im], x[2*im+1]; pu_b, tds_b = x[2*ib], x[2*ib+1]
    try: mI = float(p["main_relay"]["Ishc"]); bI = float(p["backup_relay"]["Ishc"])
    except (ValueError, TypeError, KeyError): logger.error(f"[Constr] Error Ishc {main_relay_name}/{backup_relay_name}"); return -1e6 
    t_m = timeout(mI, pu_m, tds_m); t_b = timeout(bI, pu_b, tds_b)
    if not np.isfinite(t_m) or not np.isfinite(t_b): logger.warning(f"[Constr] Tiempo no finito {main_relay_name}/{backup_relay_name}. t_m={t_m}, t_b={t_b}"); return -1e6 
    constraint_value = t_b - t_m - cti_param
    return constraint_value

# --- Función Principal ---

def run_and_unify(input_json_path, output_json_path, cti_value):
    # ... (Carga y validación de datos igual que antes) ...
    try:
        with open(input_json_path, "r", encoding='utf-8') as f: data = json.load(f)
        logger.info(f"Datos cargados desde: {input_json_path}")
    except FileNotFoundError: logger.error(f"Archivo no encontrado: {input_json_path}"); return
    except json.JSONDecodeError as e: logger.error(f"JSON inválido: {input_json_path}: {e}"); return
    except Exception as e: logger.error(f"Error lectura archivo {input_json_path}: {e}"); return
    by_scenario = defaultdict(list); required_keys = ["scenario_id", "main_relay", "backup_relay"]; required_relay_keys = ["relay", "Ishc"] 
    valid_pairs_count = 0; skipped_pairs_count = 0
    if not isinstance(data, list): logger.error(f"Contenido de {input_json_path} no es lista."); return
    for i, pair in enumerate(data): # Validación
        if not isinstance(pair, dict): logger.warning(f"Entrada {i} omitida: No es diccionario."); skipped_pairs_count += 1; continue
        if not all(k in pair for k in required_keys): logger.warning(f"Par {i} (ID: {pair.get('scenario_id', 'N/A')}) omitido: Faltan claves. Claves: {list(pair.keys())}"); skipped_pairs_count += 1; continue
        main_relay = pair.get("main_relay"); backup_relay = pair.get("backup_relay"); scenario_id_log = pair.get('scenario_id', 'N/A') 
        if not isinstance(main_relay, dict) or not isinstance(backup_relay, dict): logger.warning(f"Par {i} (Esc {scenario_id_log}) omitido: main/backup no son dict."); skipped_pairs_count += 1; continue
        if not all(k in main_relay for k in required_relay_keys) or not all(k in backup_relay for k in required_relay_keys): logger.warning(f"Par {i} (Esc {scenario_id_log}) omitido: Falta relay/Ishc. MainK: {list(main_relay.keys())}, BackupK: {list(backup_relay.keys())}"); skipped_pairs_count += 1; continue
        try: mI = float(main_relay['Ishc']); bI = float(backup_relay['Ishc']); assert np.isfinite(mI) and np.isfinite(bI) and mI > 0 and bI > 0
        except: logger.warning(f"Par {i} (Esc {scenario_id_log}) omitido: Ishc inválido (M='{main_relay.get('Ishc')}', B='{backup_relay.get('Ishc')}')."); skipped_pairs_count += 1; continue
        main_relay_name_val = main_relay.get("relay"); backup_relay_name_val = backup_relay.get("relay")
        if not isinstance(main_relay_name_val, (str, int, float)) or not isinstance(backup_relay_name_val, (str, int, float)) or str(main_relay_name_val).strip() == "" or str(backup_relay_name_val).strip() == "": logger.warning(f"Par {i} (Esc {scenario_id_log}) omitido: Nombre relé inválido (M='{main_relay_name_val}', B='{backup_relay_name_val}')."); skipped_pairs_count += 1; continue
        by_scenario[str(pair["scenario_id"])].append(pair); valid_pairs_count += 1
    logger.info(f"Agrupados {valid_pairs_count} pares válidos en {len(by_scenario)} escenarios. Omitidos: {skipped_pairs_count}.")
    if not by_scenario: logger.error("No hay escenarios válidos."); return
        
    unified = []
    optimization_stats = {}
    
    for scen, pairs in by_scenario.items(): 
        logger.info(f"--- Procesando Escenario: {scen} ({len(pairs)} pares) ---")
        if not pairs: logger.warning(f"Escenario {scen} sin pares válidos iniciales. Omitiendo."); scenario_result_data = { "_id": {"$oid": str(uuid.uuid4())}, "scenario_id": scen, "timestamp": datetime.datetime.utcnow().isoformat(timespec='milliseconds') + "Z", "optimization_method": None, "relay_values": {}, "optimization_status": -3, "optimization_success": False, "optimization_message": "Skipped - No valid pairs in input", "objective_function_value": None, "optimization_iterations": None, "optimization_time_seconds": 0.0 }; unified.append(scenario_result_data); optimization_stats[scen] = {"success": False, "status": -3, "message": "Skipped - No input pairs"}; continue 
        relays = OrderedDict(); 
        for p in pairs: relays[str(p["main_relay"]["relay"])] = None; relays[str(p["backup_relay"]["relay"])] = None
        relay_list = list(relays.keys()); relay_idx = {r: i for i, r in enumerate(relay_list)}; num_relays = len(relay_list); num_vars = num_relays * 2 
        logger.info(f"Relés únicos a optimizar en {scen}: {num_relays}")

        # Inicialización x0
        x0 = np.zeros(num_vars); initialized_relays = set()
        for p in pairs: 
             for side in ("main_relay", "backup_relay"):
                 relay_info = p[side]; r_name = str(relay_info["relay"])
                 if r_name not in initialized_relays and r_name in relay_idx: 
                     i = relay_idx[r_name]; pu_init_val = relay_info.get("pickup"); tds_init_val = relay_info.get("TDS")
                     try: pu_init = float(pu_init_val) if pu_init_val is not None else (IPI_MIN + IPI_MAX) / 2
                     except: pu_init = (IPI_MIN + IPI_MAX) / 2
                     try: tds_init = float(tds_init_val) if tds_init_val is not None else (TDS_MIN + TDS_MAX) / 2
                     except: tds_init = (TDS_MIN + TDS_MAX) / 2
                     x0[2*i] = np.clip(pu_init, IPI_MIN, IPI_MAX); x0[2*i+1] = np.clip(tds_init, TDS_MIN, TDS_MAX); initialized_relays.add(r_name)
                     
        # Límites (Bounds) para SLSQP (lista de tuplas)
        bnds = [(IPI_MIN, IPI_MAX), (TDS_MIN, TDS_MAX)] * num_relays 
        
        # Restricciones (Constraints) para SLSQP (lista de diccionarios)
        cons = []
        for p_idx, p in enumerate(pairs): 
             # Usar la función de restricción original (no vectorizada)
             constraint_func = lambda x, p_local=p: constraint_delta_t(x, p_local, relay_idx, k, n, cti_value)
             cons.append({"type": "ineq", "fun": constraint_func}) # 'ineq' significa func >= 0
        logger.info(f"Número de restricciones de coordinación para {scen}: {len(cons)}")

        # --- Ejecutar la optimización con SLSQP y tolerancias relajadas ---
        obj_args = (pairs, relay_idx, alpha1, alpha2, k, n, cti_value) 
        optimization_method = "SLSQP" # Volver a SLSQP
        logger.info(f"Iniciando optimización para {scen} con método {optimization_method} (tolerancias relajadas)...")
        
        # --- CAMBIO: Opciones con tolerancias más relajadas ---
        # ftol: Tolerancia en cambio de función objetivo
        # Aumentar ligeramente de 1e-7 a 1e-5 (o 1e-4 si sigue fallando)
        # Reducir maxiter un poco para evitar esperas largas si falla
        options = {'maxiter': 800, 'ftol': 1e-5, 'disp': False} 
                     
        start_time = datetime.datetime.now()
        try:
            if len(x0) != num_vars: raise ValueError(f"Tamaño x0 ({len(x0)}) != num_vars ({num_vars}) en {scen}")
            
            # Llamada a minimize con SLSQP y nuevas opciones
            res = minimize(
                objective_scenario, 
                x0, 
                args=obj_args, 
                method=optimization_method, 
                bounds=bnds, # Lista de tuplas para SLSQP
                constraints=cons, # Lista de diccionarios para SLSQP
                options=options
            )
            
            end_time = datetime.datetime.now(); duration = (end_time - start_time).total_seconds()
            logger.info(f"Optimización {scen} ({duration:.2f}s). Estado: {res.status} ({res.message})")
            if not res.success: logger.warning(f"Fallo optimización {scen}: {res.message} (Status={res.status})") # Log más claro del fallo
            # logger.debug(f"Resultado completo {scen}: {res}") # Descomentar para depuración extrema
            logger.info(f"Valor OF final {scen}: {res.fun if res.success else 'N/A'}") # Mostrar OF solo si tuvo éxito
            optimization_successful = res.success
                 
        except ValueError as e:
             end_time = datetime.datetime.now(); duration = (end_time - start_time).total_seconds()
             logger.error(f"Error (ValueError) optimización {scen} ({duration:.2f}s): {e}", exc_info=True)
             optimization_successful = False; res = None 
        except Exception as e:
             end_time = datetime.datetime.now(); duration = (end_time - start_time).total_seconds()
             logger.error(f"Excepción inesperada optimización {scen} ({duration:.2f}s): {e}", exc_info=True)
             optimization_successful = False; res = None

        # --- Procesar y guardar resultados ---
        # Formato de salida ajustado para coincidir con el ejemplo deseado
        
        scenario_result_data = {
             # "_id": {"$oid": str(uuid.uuid4())}, # Omitido si no es necesario para MongoDB
             "scenario_id": scen,
             "timestamp": datetime.datetime.utcnow().isoformat(timespec='microseconds') + "+00:00", # Formato ejemplo
             # Incluir detalles de optimización aunque falle, si están disponibles
             "optimization_details": { 
                 "method": optimization_method,
                 "success": False, # Default a Falso
                 "status": -1 if res is None else res.status,
                 "message": "Optimization failed due to error" if res is None else res.message,
                 "iterations": None,
                 "time_seconds": round(duration, 3),
                 "final_objective_value": None
             },
             "relay_values": {} # Default a vacío
        }

        if res is not None: # Actualizar detalles si res existe
             scenario_result_data["optimization_details"]["success"] = bool(res.success)
             scenario_result_data["optimization_details"]["status"] = res.status
             scenario_result_data["optimization_details"]["message"] = res.message
             if hasattr(res, 'nit'): scenario_result_data["optimization_details"]["iterations"] = int(res.nit)
             if res.success and np.isfinite(res.fun): scenario_result_data["optimization_details"]["final_objective_value"] = float(res.fun)
                 
        if optimization_successful and res is not None:
            x_opt = res.x.copy(); final_relay_values = {}
            for r_name, i in relay_idx.items(): 
                # Redondear TDS al paso más cercano ANTES de aplicar clip
                tds_opt_rounded = np.round(x_opt[2*i+1] / TDS_STEP) * TDS_STEP
                # Aplicar clip a ambos valores
                pickup_opt = np.clip(x_opt[2*i], IPI_MIN, IPI_MAX)
                tds_opt_final = np.clip(tds_opt_rounded, TDS_MIN, TDS_MAX)
                # Guardar con el formato del ejemplo
                final_relay_values[r_name] = {"TDS": float(tds_opt_final), "pickup": float(pickup_opt)} 
            
            scenario_result_data["relay_values"] = final_relay_values # Actualizar relay_values
            optimization_stats[scen] = {"success": True, "status": res.status, "message": res.message, "obj_func": res.fun}
        else:
            logger.warning(f"Optimización fallida/incompleta para {scen}. No se guardarán relay_values.")
            optimization_stats[scen] = {"success": False, "status": -1 if res is None else res.status, "message": "Failed/Error" if res is None else res.message}
        
        unified.append(scenario_result_data) # Añadir resultado (con o sin relay_values)

    # --- Fin del bucle de escenarios ---
    # ... (Resumen y guardado igual que antes) ...
    successful_scenarios = sum(1 for s in optimization_stats.values() if s["success"])
    skipped_scenarios = sum(1 for s in optimization_stats.values() if s.get("status") == -3) # Usar get por si acaso
    failed_scenarios = len(by_scenario) - successful_scenarios - skipped_scenarios
    logger.info(f"\n--- Resumen Optimización ---")
    logger.info(f"Escenarios leídos: {len(by_scenario)}")
    logger.info(f"  Optimizados Exitosamente: {successful_scenarios}")
    logger.info(f"  Fallidos/Incompletos: {failed_scenarios}")
    logger.info(f"  Omitidos (sin pares válidos iniciales): {skipped_scenarios}")
    if failed_scenarios > 0 or skipped_scenarios > 0:
        logger.warning("Escenarios con optimización fallida, incompleta u omitida:")
        for scen, stats in optimization_stats.items():
             if not stats.get("success", False): # Usar get por si acaso
                 status_desc = "Omitido (Sin Pares Iniciales)" if stats.get('status') == -3 else f"Fallido/Incompleto (Status={stats.get('status', 'N/A')})"
                 logger.warning(f"  - {scen}: {status_desc}, Message='{stats.get('message', 'N/A')}'")
    try:
        output_dir = os.path.dirname(output_json_path);
        if output_dir and not os.path.exists(output_dir): os.makedirs(output_dir); logger.info(f"Directorio salida creado: {output_dir}")
        with open(output_json_path, "w", encoding='utf-8') as f: json.dump(unified, f, indent=2, ensure_ascii=False) 
        logger.info(f"Archivo unificado guardado en: {output_json_path}")
    except IOError as e: logger.error(f"Error E/S al guardar JSON en {output_json_path}: {e}", exc_info=True)
    except Exception as e: logger.error(f"Error inesperado al guardar JSON: {e}", exc_info=True)

# --- Punto de Entrada ---
if __name__ == "__main__":
    run_and_unify(input_json_path=INPUT_JSON, 
                  output_json_path=OUTPUT_JSON, 
                  cti_value=CTI)
# Out:
# 2025-04-20 14:11:12,946 - INFO - Datos cargados desde: /Users/gustavo/Documents/Projects/TESIS_UNAL/ADAPTIVE_ALGORITHM/data/processed/independent_relay_pairs.json
# 2025-04-20 14:11:12,950 - WARNING - Par 126 (Esc scenario_2) omitido: Ishc inválido (M='0.64', B='0').
# 2025-04-20 14:11:12,950 - WARNING - Par 129 (Esc scenario_2) omitido: Ishc inválido (M='0.43', B='0').
# 2025-04-20 14:11:12,951 - WARNING - Par 226 (Esc scenario_3) omitido: Ishc inválido (M='0.67', B='0').
# 2025-04-20 14:11:12,952 - WARNING - Par 229 (Esc scenario_3) omitido: Ishc inválido (M='0.45', B='0').
# 2025-04-20 14:11:12,952 - WARNING - Par 291 (Esc scenario_3) omitido: Ishc inválido (M='1.49', B='0').
# 2025-04-20 14:11:12,954 - WARNING - Par 426 (Esc scenario_5) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:12,955 - WARNING - Par 429 (Esc scenario_5) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:12,958 - WARNING - Par 526 (Esc scenario_6) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:12,960 - WARNING - Par 529 (Esc scenario_6) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:12,962 - WARNING - Par 626 (Esc scenario_7) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:12,964 - WARNING - Par 629 (Esc scenario_7) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:12,966 - WARNING - Par 726 (Esc scenario_8) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:12,968 - WARNING - Par 729 (Esc scenario_8) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:12,972 - WARNING - Par 826 (Esc scenario_9) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:12,973 - WARNING - Par 829 (Esc scenario_9) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:13,036 - WARNING - Par 926 (Esc scenario_10) omitido: Ishc inválido (M='0.64', B='0').
# 2025-04-20 14:11:13,039 - WARNING - Par 929 (Esc scenario_10) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:13,058 - WARNING - Par 1026 (Esc scenario_11) omitido: Ishc inválido (M='0.63', B='0').
# 2025-04-20 14:11:13,062 - WARNING - Par 1029 (Esc scenario_11) omitido: Ishc inválido (M='0.43', B='0').
# 2025-04-20 14:11:13,065 - WARNING - Par 1126 (Esc scenario_12) omitido: Ishc inválido (M='0.63', B='0').
# 2025-04-20 14:11:13,066 - WARNING - Par 1129 (Esc scenario_12) omitido: Ishc inválido (M='0.43', B='0').
# 2025-04-20 14:11:13,067 - WARNING - Par 1226 (Esc scenario_13) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:13,067 - WARNING - Par 1229 (Esc scenario_13) omitido: Ishc inválido (M='0.45', B='0').
# 2025-04-20 14:11:13,068 - WARNING - Par 1326 (Esc scenario_14) omitido: Ishc inválido (M='0.66', B='0').
# 2025-04-20 14:11:13,068 - WARNING - Par 1329 (Esc scenario_14) omitido: Ishc inválido (M='0.45', B='0').
# 2025-04-20 14:11:13,069 - WARNING - Par 1426 (Esc scenario_15) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:13,069 - WARNING - Par 1429 (Esc scenario_15) omitido: Ishc inválido (M='0.45', B='0').
# 2025-04-20 14:11:13,069 - WARNING - Par 1526 (Esc scenario_16) omitido: Ishc inválido (M='0.66', B='0').
# 2025-04-20 14:11:13,070 - WARNING - Par 1529 (Esc scenario_16) omitido: Ishc inválido (M='0.45', B='0').
# 2025-04-20 14:11:13,070 - WARNING - Par 1626 (Esc scenario_17) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:13,070 - WARNING - Par 1629 (Esc scenario_17) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:13,072 - WARNING - Par 1726 (Esc scenario_18) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:13,072 - WARNING - Par 1729 (Esc scenario_18) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:13,073 - WARNING - Par 1826 (Esc scenario_19) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:13,074 - WARNING - Par 1829 (Esc scenario_19) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:13,075 - WARNING - Par 1926 (Esc scenario_20) omitido: Ishc inválido (M='0.65', B='0').
# 2025-04-20 14:11:13,076 - WARNING - Par 1929 (Esc scenario_20) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:13,082 - WARNING - Par 3626 (Esc scenario_37) omitido: Ishc inválido (M='0.67', B='0').
# 2025-04-20 14:11:13,082 - WARNING - Par 3629 (Esc scenario_37) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,083 - WARNING - Par 3691 (Esc scenario_37) omitido: Ishc inválido (M='1.52', B='0').
# 2025-04-20 14:11:13,084 - WARNING - Par 3726 (Esc scenario_38) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,085 - WARNING - Par 3729 (Esc scenario_38) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,093 - WARNING - Par 3791 (Esc scenario_38) omitido: Ishc inválido (M='1.53', B='0').
# 2025-04-20 14:11:13,094 - WARNING - Par 3826 (Esc scenario_39) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,095 - WARNING - Par 3829 (Esc scenario_39) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,095 - WARNING - Par 3891 (Esc scenario_39) omitido: Ishc inválido (M='1.53', B='0').
# 2025-04-20 14:11:13,096 - WARNING - Par 3926 (Esc scenario_40) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,096 - WARNING - Par 3929 (Esc scenario_40) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,097 - WARNING - Par 4026 (Esc scenario_41) omitido: Ishc inválido (M='0.67', B='0').
# 2025-04-20 14:11:13,098 - WARNING - Par 4029 (Esc scenario_41) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,098 - WARNING - Par 4091 (Esc scenario_41) omitido: Ishc inválido (M='1.52', B='0').
# 2025-04-20 14:11:13,101 - WARNING - Par 4126 (Esc scenario_42) omitido: Ishc inválido (M='0.67', B='0').
# 2025-04-20 14:11:13,102 - WARNING - Par 4129 (Esc scenario_42) omitido: Ishc inválido (M='0.45', B='0').
# 2025-04-20 14:11:13,103 - WARNING - Par 4191 (Esc scenario_42) omitido: Ishc inválido (M='1.5', B='0').
# 2025-04-20 14:11:13,104 - WARNING - Par 4226 (Esc scenario_43) omitido: Ishc inválido (M='0.66', B='0').
# 2025-04-20 14:11:13,105 - WARNING - Par 4229 (Esc scenario_43) omitido: Ishc inválido (M='0.45', B='0').
# 2025-04-20 14:11:13,105 - WARNING - Par 4291 (Esc scenario_43) omitido: Ishc inválido (M='1.48', B='0').
# 2025-04-20 14:11:13,106 - WARNING - Par 4326 (Esc scenario_44) omitido: Ishc inválido (M='0.66', B='0').
# 2025-04-20 14:11:13,107 - WARNING - Par 4329 (Esc scenario_44) omitido: Ishc inválido (M='0.44', B='0').
# 2025-04-20 14:11:13,108 - WARNING - Par 4391 (Esc scenario_44) omitido: Ishc inválido (M='1.46', B='0').
# 2025-04-20 14:11:13,109 - WARNING - Par 4426 (Esc scenario_45) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,111 - WARNING - Par 4429 (Esc scenario_45) omitido: Ishc inválido (M='0.47', B='0').
# 2025-04-20 14:11:13,112 - WARNING - Par 4491 (Esc scenario_45) omitido: Ishc inválido (M='1.55', B='0').
# 2025-04-20 14:11:13,113 - WARNING - Par 4526 (Esc scenario_46) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,114 - WARNING - Par 4529 (Esc scenario_46) omitido: Ishc inválido (M='0.47', B='0').
# 2025-04-20 14:11:13,115 - WARNING - Par 4591 (Esc scenario_46) omitido: Ishc inválido (M='1.56', B='0').
# 2025-04-20 14:11:13,115 - WARNING - Par 4626 (Esc scenario_47) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,116 - WARNING - Par 4629 (Esc scenario_47) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,116 - WARNING - Par 4691 (Esc scenario_47) omitido: Ishc inválido (M='1.54', B='0').
# 2025-04-20 14:11:13,117 - WARNING - Par 4726 (Esc scenario_48) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,118 - WARNING - Par 4729 (Esc scenario_48) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,119 - WARNING - Par 4791 (Esc scenario_48) omitido: Ishc inválido (M='1.55', B='0').
# 2025-04-20 14:11:13,120 - WARNING - Par 4826 (Esc scenario_49) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,121 - WARNING - Par 4829 (Esc scenario_49) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,122 - WARNING - Par 4926 (Esc scenario_50) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,123 - WARNING - Par 4929 (Esc scenario_50) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,132 - WARNING - Par 5026 (Esc scenario_51) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,133 - WARNING - Par 5029 (Esc scenario_51) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,137 - WARNING - Par 5126 (Esc scenario_52) omitido: Ishc inválido (M='0.68', B='0').
# 2025-04-20 14:11:13,140 - WARNING - Par 5129 (Esc scenario_52) omitido: Ishc inválido (M='0.46', B='0').
# 2025-04-20 14:11:13,152 - INFO - Agrupados 6720 pares válidos en 68 escenarios. Omitidos: 80.
# 2025-04-20 14:11:13,154 - INFO - --- Procesando Escenario: scenario_1 (100 pares) ---
# 2025-04-20 14:11:13,156 - INFO - Relés únicos a optimizar en scenario_1: 74
# 2025-04-20 14:11:13,163 - INFO - Número de restricciones de coordinación para scenario_1: 100
# 2025-04-20 14:11:13,166 - INFO - Iniciando optimización para scenario_1 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:18,771 - INFO - Optimización scenario_1 (5.60s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:18,773 - WARNING - Fallo optimización scenario_1: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:18,773 - INFO - Valor OF final scenario_1: N/A
# 2025-04-20 14:11:18,774 - WARNING - Optimización fallida/incompleta para scenario_1. No se guardarán relay_values.
# 2025-04-20 14:11:18,774 - INFO - --- Procesando Escenario: scenario_2 (98 pares) ---
# 2025-04-20 14:11:18,774 - INFO - Relés únicos a optimizar en scenario_2: 73
# 2025-04-20 14:11:18,775 - INFO - Número de restricciones de coordinación para scenario_2: 98
# 2025-04-20 14:11:18,776 - INFO - Iniciando optimización para scenario_2 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:18,977 - INFO - Optimización scenario_2 (0.20s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:18,978 - WARNING - Fallo optimización scenario_2: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:18,978 - INFO - Valor OF final scenario_2: N/A
# 2025-04-20 14:11:18,978 - WARNING - Optimización fallida/incompleta para scenario_2. No se guardarán relay_values.
# 2025-04-20 14:11:18,979 - INFO - --- Procesando Escenario: scenario_3 (97 pares) ---
# 2025-04-20 14:11:18,981 - INFO - Relés únicos a optimizar en scenario_3: 73
# 2025-04-20 14:11:18,985 - INFO - Número de restricciones de coordinación para scenario_3: 97
# 2025-04-20 14:11:18,986 - INFO - Iniciando optimización para scenario_3 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:19,370 - INFO - Optimización scenario_3 (0.38s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:19,371 - WARNING - Fallo optimización scenario_3: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:19,371 - INFO - Valor OF final scenario_3: N/A
# 2025-04-20 14:11:19,371 - WARNING - Optimización fallida/incompleta para scenario_3. No se guardarán relay_values.
# 2025-04-20 14:11:19,372 - INFO - --- Procesando Escenario: scenario_4 (100 pares) ---
# 2025-04-20 14:11:19,372 - INFO - Relés únicos a optimizar en scenario_4: 74
# 2025-04-20 14:11:19,376 - INFO - Número de restricciones de coordinación para scenario_4: 100
# 2025-04-20 14:11:19,377 - INFO - Iniciando optimización para scenario_4 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:19,666 - INFO - Optimización scenario_4 (0.29s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:19,666 - WARNING - Fallo optimización scenario_4: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:19,666 - INFO - Valor OF final scenario_4: N/A
# 2025-04-20 14:11:19,666 - WARNING - Optimización fallida/incompleta para scenario_4. No se guardarán relay_values.
# 2025-04-20 14:11:19,667 - INFO - --- Procesando Escenario: scenario_5 (98 pares) ---
# 2025-04-20 14:11:19,668 - INFO - Relés únicos a optimizar en scenario_5: 73
# 2025-04-20 14:11:19,675 - INFO - Número de restricciones de coordinación para scenario_5: 98
# 2025-04-20 14:11:19,677 - INFO - Iniciando optimización para scenario_5 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:19,856 - INFO - Optimización scenario_5 (0.18s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:19,857 - WARNING - Fallo optimización scenario_5: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:19,857 - INFO - Valor OF final scenario_5: N/A
# 2025-04-20 14:11:19,857 - WARNING - Optimización fallida/incompleta para scenario_5. No se guardarán relay_values.
# 2025-04-20 14:11:19,858 - INFO - --- Procesando Escenario: scenario_6 (98 pares) ---
# 2025-04-20 14:11:19,859 - INFO - Relés únicos a optimizar en scenario_6: 73
# 2025-04-20 14:11:19,863 - INFO - Número de restricciones de coordinación para scenario_6: 98
# 2025-04-20 14:11:19,864 - INFO - Iniciando optimización para scenario_6 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:20,162 - INFO - Optimización scenario_6 (0.30s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:20,163 - WARNING - Fallo optimización scenario_6: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:20,163 - INFO - Valor OF final scenario_6: N/A
# 2025-04-20 14:11:20,163 - WARNING - Optimización fallida/incompleta para scenario_6. No se guardarán relay_values.
# 2025-04-20 14:11:20,163 - INFO - --- Procesando Escenario: scenario_7 (98 pares) ---
# 2025-04-20 14:11:20,164 - INFO - Relés únicos a optimizar en scenario_7: 73
# 2025-04-20 14:11:20,166 - INFO - Número de restricciones de coordinación para scenario_7: 98
# 2025-04-20 14:11:20,167 - INFO - Iniciando optimización para scenario_7 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:20,341 - INFO - Optimización scenario_7 (0.17s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:20,342 - WARNING - Fallo optimización scenario_7: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:20,342 - INFO - Valor OF final scenario_7: N/A
# 2025-04-20 14:11:20,342 - WARNING - Optimización fallida/incompleta para scenario_7. No se guardarán relay_values.
# 2025-04-20 14:11:20,342 - INFO - --- Procesando Escenario: scenario_8 (98 pares) ---
# 2025-04-20 14:11:20,343 - INFO - Relés únicos a optimizar en scenario_8: 73
# 2025-04-20 14:11:20,350 - INFO - Número de restricciones de coordinación para scenario_8: 98
# 2025-04-20 14:11:20,351 - INFO - Iniciando optimización para scenario_8 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:20,603 - INFO - Optimización scenario_8 (0.25s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:20,603 - WARNING - Fallo optimización scenario_8: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:20,604 - INFO - Valor OF final scenario_8: N/A
# 2025-04-20 14:11:20,604 - WARNING - Optimización fallida/incompleta para scenario_8. No se guardarán relay_values.
# 2025-04-20 14:11:20,604 - INFO - --- Procesando Escenario: scenario_9 (98 pares) ---
# 2025-04-20 14:11:20,605 - INFO - Relés únicos a optimizar en scenario_9: 73
# 2025-04-20 14:11:20,612 - INFO - Número de restricciones de coordinación para scenario_9: 98
# 2025-04-20 14:11:20,613 - INFO - Iniciando optimización para scenario_9 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:20,792 - INFO - Optimización scenario_9 (0.18s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:20,792 - WARNING - Fallo optimización scenario_9: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:20,792 - INFO - Valor OF final scenario_9: N/A
# 2025-04-20 14:11:20,792 - WARNING - Optimización fallida/incompleta para scenario_9. No se guardarán relay_values.
# 2025-04-20 14:11:20,794 - INFO - --- Procesando Escenario: scenario_10 (98 pares) ---
# 2025-04-20 14:11:20,795 - INFO - Relés únicos a optimizar en scenario_10: 73
# 2025-04-20 14:11:20,797 - INFO - Número de restricciones de coordinación para scenario_10: 98
# 2025-04-20 14:11:20,798 - INFO - Iniciando optimización para scenario_10 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:21,059 - INFO - Optimización scenario_10 (0.26s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:21,059 - WARNING - Fallo optimización scenario_10: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:21,059 - INFO - Valor OF final scenario_10: N/A
# 2025-04-20 14:11:21,060 - WARNING - Optimización fallida/incompleta para scenario_10. No se guardarán relay_values.
# 2025-04-20 14:11:21,060 - INFO - --- Procesando Escenario: scenario_11 (98 pares) ---
# 2025-04-20 14:11:21,060 - INFO - Relés únicos a optimizar en scenario_11: 73
# 2025-04-20 14:11:21,063 - INFO - Número de restricciones de coordinación para scenario_11: 98
# 2025-04-20 14:11:21,064 - INFO - Iniciando optimización para scenario_11 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:21,226 - INFO - Optimización scenario_11 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:21,226 - WARNING - Fallo optimización scenario_11: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:21,226 - INFO - Valor OF final scenario_11: N/A
# 2025-04-20 14:11:21,226 - WARNING - Optimización fallida/incompleta para scenario_11. No se guardarán relay_values.
# 2025-04-20 14:11:21,227 - INFO - --- Procesando Escenario: scenario_12 (98 pares) ---
# 2025-04-20 14:11:21,228 - INFO - Relés únicos a optimizar en scenario_12: 73
# 2025-04-20 14:11:21,234 - INFO - Número de restricciones de coordinación para scenario_12: 98
# 2025-04-20 14:11:21,234 - INFO - Iniciando optimización para scenario_12 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:21,465 - INFO - Optimización scenario_12 (0.23s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:21,465 - WARNING - Fallo optimización scenario_12: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:21,465 - INFO - Valor OF final scenario_12: N/A
# 2025-04-20 14:11:21,465 - WARNING - Optimización fallida/incompleta para scenario_12. No se guardarán relay_values.
# 2025-04-20 14:11:21,466 - INFO - --- Procesando Escenario: scenario_13 (98 pares) ---
# 2025-04-20 14:11:21,467 - INFO - Relés únicos a optimizar en scenario_13: 73
# 2025-04-20 14:11:21,473 - INFO - Número de restricciones de coordinación para scenario_13: 98
# 2025-04-20 14:11:21,474 - INFO - Iniciando optimización para scenario_13 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:21,630 - INFO - Optimización scenario_13 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:21,631 - WARNING - Fallo optimización scenario_13: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:21,631 - INFO - Valor OF final scenario_13: N/A
# 2025-04-20 14:11:21,631 - WARNING - Optimización fallida/incompleta para scenario_13. No se guardarán relay_values.
# 2025-04-20 14:11:21,631 - INFO - --- Procesando Escenario: scenario_14 (98 pares) ---
# 2025-04-20 14:11:21,632 - INFO - Relés únicos a optimizar en scenario_14: 73
# 2025-04-20 14:11:21,640 - INFO - Número de restricciones de coordinación para scenario_14: 98
# 2025-04-20 14:11:21,640 - INFO - Iniciando optimización para scenario_14 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:21,800 - INFO - Optimización scenario_14 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:21,800 - WARNING - Fallo optimización scenario_14: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:21,801 - INFO - Valor OF final scenario_14: N/A
# 2025-04-20 14:11:21,801 - WARNING - Optimización fallida/incompleta para scenario_14. No se guardarán relay_values.
# 2025-04-20 14:11:21,802 - INFO - --- Procesando Escenario: scenario_15 (98 pares) ---
# 2025-04-20 14:11:21,803 - INFO - Relés únicos a optimizar en scenario_15: 73
# 2025-04-20 14:11:21,807 - INFO - Número de restricciones de coordinación para scenario_15: 98
# 2025-04-20 14:11:21,807 - INFO - Iniciando optimización para scenario_15 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:22,039 - INFO - Optimización scenario_15 (0.23s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:22,039 - WARNING - Fallo optimización scenario_15: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:22,039 - INFO - Valor OF final scenario_15: N/A
# 2025-04-20 14:11:22,040 - WARNING - Optimización fallida/incompleta para scenario_15. No se guardarán relay_values.
# 2025-04-20 14:11:22,040 - INFO - --- Procesando Escenario: scenario_16 (98 pares) ---
# 2025-04-20 14:11:22,041 - INFO - Relés únicos a optimizar en scenario_16: 73
# 2025-04-20 14:11:22,048 - INFO - Número de restricciones de coordinación para scenario_16: 98
# 2025-04-20 14:11:22,049 - INFO - Iniciando optimización para scenario_16 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:22,215 - INFO - Optimización scenario_16 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:22,215 - WARNING - Fallo optimización scenario_16: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:22,215 - INFO - Valor OF final scenario_16: N/A
# 2025-04-20 14:11:22,215 - WARNING - Optimización fallida/incompleta para scenario_16. No se guardarán relay_values.
# 2025-04-20 14:11:22,216 - INFO - --- Procesando Escenario: scenario_17 (98 pares) ---
# 2025-04-20 14:11:22,216 - INFO - Relés únicos a optimizar en scenario_17: 73
# 2025-04-20 14:11:22,218 - INFO - Número de restricciones de coordinación para scenario_17: 98
# 2025-04-20 14:11:22,220 - INFO - Iniciando optimización para scenario_17 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:22,383 - INFO - Optimización scenario_17 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:22,383 - WARNING - Fallo optimización scenario_17: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:22,383 - INFO - Valor OF final scenario_17: N/A
# 2025-04-20 14:11:22,384 - WARNING - Optimización fallida/incompleta para scenario_17. No se guardarán relay_values.
# 2025-04-20 14:11:22,384 - INFO - --- Procesando Escenario: scenario_18 (98 pares) ---
# 2025-04-20 14:11:22,384 - INFO - Relés únicos a optimizar en scenario_18: 73
# 2025-04-20 14:11:22,390 - INFO - Número de restricciones de coordinación para scenario_18: 98
# 2025-04-20 14:11:22,390 - INFO - Iniciando optimización para scenario_18 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:22,628 - INFO - Optimización scenario_18 (0.24s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:22,628 - WARNING - Fallo optimización scenario_18: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:22,629 - INFO - Valor OF final scenario_18: N/A
# 2025-04-20 14:11:22,629 - WARNING - Optimización fallida/incompleta para scenario_18. No se guardarán relay_values.
# 2025-04-20 14:11:22,629 - INFO - --- Procesando Escenario: scenario_19 (98 pares) ---
# 2025-04-20 14:11:22,629 - INFO - Relés únicos a optimizar en scenario_19: 73
# 2025-04-20 14:11:22,630 - INFO - Número de restricciones de coordinación para scenario_19: 98
# 2025-04-20 14:11:22,631 - INFO - Iniciando optimización para scenario_19 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:22,819 - INFO - Optimización scenario_19 (0.19s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:22,819 - WARNING - Fallo optimización scenario_19: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:22,819 - INFO - Valor OF final scenario_19: N/A
# 2025-04-20 14:11:22,820 - WARNING - Optimización fallida/incompleta para scenario_19. No se guardarán relay_values.
# 2025-04-20 14:11:22,821 - INFO - --- Procesando Escenario: scenario_20 (98 pares) ---
# 2025-04-20 14:11:22,822 - INFO - Relés únicos a optimizar en scenario_20: 73
# 2025-04-20 14:11:22,826 - INFO - Número de restricciones de coordinación para scenario_20: 98
# 2025-04-20 14:11:22,827 - INFO - Iniciando optimización para scenario_20 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:22,985 - INFO - Optimización scenario_20 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:22,985 - WARNING - Fallo optimización scenario_20: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:22,985 - INFO - Valor OF final scenario_20: N/A
# 2025-04-20 14:11:22,986 - WARNING - Optimización fallida/incompleta para scenario_20. No se guardarán relay_values.
# 2025-04-20 14:11:22,986 - INFO - --- Procesando Escenario: scenario_21 (100 pares) ---
# 2025-04-20 14:11:22,987 - INFO - Relés únicos a optimizar en scenario_21: 74
# 2025-04-20 14:11:22,993 - INFO - Número de restricciones de coordinación para scenario_21: 100
# 2025-04-20 14:11:22,993 - INFO - Iniciando optimización para scenario_21 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:23,310 - INFO - Optimización scenario_21 (0.32s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:23,310 - WARNING - Fallo optimización scenario_21: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:23,310 - INFO - Valor OF final scenario_21: N/A
# 2025-04-20 14:11:23,310 - WARNING - Optimización fallida/incompleta para scenario_21. No se guardarán relay_values.
# 2025-04-20 14:11:23,311 - INFO - --- Procesando Escenario: scenario_22 (100 pares) ---
# 2025-04-20 14:11:23,312 - INFO - Relés únicos a optimizar en scenario_22: 74
# 2025-04-20 14:11:23,317 - INFO - Número de restricciones de coordinación para scenario_22: 100
# 2025-04-20 14:11:23,318 - INFO - Iniciando optimización para scenario_22 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:23,564 - INFO - Optimización scenario_22 (0.25s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:23,564 - WARNING - Fallo optimización scenario_22: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:23,564 - INFO - Valor OF final scenario_22: N/A
# 2025-04-20 14:11:23,564 - WARNING - Optimización fallida/incompleta para scenario_22. No se guardarán relay_values.
# 2025-04-20 14:11:23,565 - INFO - --- Procesando Escenario: scenario_23 (100 pares) ---
# 2025-04-20 14:11:23,565 - INFO - Relés únicos a optimizar en scenario_23: 74
# 2025-04-20 14:11:23,572 - INFO - Número de restricciones de coordinación para scenario_23: 100
# 2025-04-20 14:11:23,573 - INFO - Iniciando optimización para scenario_23 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:23,822 - INFO - Optimización scenario_23 (0.25s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:23,823 - WARNING - Fallo optimización scenario_23: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:23,823 - INFO - Valor OF final scenario_23: N/A
# 2025-04-20 14:11:23,823 - WARNING - Optimización fallida/incompleta para scenario_23. No se guardarán relay_values.
# 2025-04-20 14:11:23,824 - INFO - --- Procesando Escenario: scenario_24 (100 pares) ---
# 2025-04-20 14:11:23,825 - INFO - Relés únicos a optimizar en scenario_24: 74
# 2025-04-20 14:11:23,831 - INFO - Número de restricciones de coordinación para scenario_24: 100
# 2025-04-20 14:11:23,831 - INFO - Iniciando optimización para scenario_24 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:24,399 - INFO - Optimización scenario_24 (0.57s). Estado: 4 (Inequality constraints incompatible)
# 2025-04-20 14:11:24,400 - WARNING - Fallo optimización scenario_24: Inequality constraints incompatible (Status=4)
# 2025-04-20 14:11:24,400 - INFO - Valor OF final scenario_24: N/A
# 2025-04-20 14:11:24,400 - WARNING - Optimización fallida/incompleta para scenario_24. No se guardarán relay_values.
# 2025-04-20 14:11:24,400 - INFO - --- Procesando Escenario: scenario_25 (100 pares) ---
# 2025-04-20 14:11:24,401 - INFO - Relés únicos a optimizar en scenario_25: 74
# 2025-04-20 14:11:24,407 - INFO - Número de restricciones de coordinación para scenario_25: 100
# 2025-04-20 14:11:24,408 - INFO - Iniciando optimización para scenario_25 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:31,686 - INFO - Optimización scenario_25 (7.28s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:31,687 - WARNING - Fallo optimización scenario_25: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:31,688 - INFO - Valor OF final scenario_25: N/A
# 2025-04-20 14:11:31,688 - WARNING - Optimización fallida/incompleta para scenario_25. No se guardarán relay_values.
# 2025-04-20 14:11:31,688 - INFO - --- Procesando Escenario: scenario_26 (100 pares) ---
# 2025-04-20 14:11:31,688 - INFO - Relés únicos a optimizar en scenario_26: 74
# 2025-04-20 14:11:31,690 - INFO - Número de restricciones de coordinación para scenario_26: 100
# 2025-04-20 14:11:31,693 - INFO - Iniciando optimización para scenario_26 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:31,964 - INFO - Optimización scenario_26 (0.27s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:31,965 - WARNING - Fallo optimización scenario_26: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:31,965 - INFO - Valor OF final scenario_26: N/A
# 2025-04-20 14:11:31,965 - WARNING - Optimización fallida/incompleta para scenario_26. No se guardarán relay_values.
# 2025-04-20 14:11:31,965 - INFO - --- Procesando Escenario: scenario_27 (100 pares) ---
# 2025-04-20 14:11:31,966 - INFO - Relés únicos a optimizar en scenario_27: 74
# 2025-04-20 14:11:31,967 - INFO - Número de restricciones de coordinación para scenario_27: 100
# 2025-04-20 14:11:31,971 - INFO - Iniciando optimización para scenario_27 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:32,367 - INFO - Optimización scenario_27 (0.39s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:32,367 - WARNING - Fallo optimización scenario_27: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:32,367 - INFO - Valor OF final scenario_27: N/A
# 2025-04-20 14:11:32,367 - WARNING - Optimización fallida/incompleta para scenario_27. No se guardarán relay_values.
# 2025-04-20 14:11:32,368 - INFO - --- Procesando Escenario: scenario_28 (100 pares) ---
# 2025-04-20 14:11:32,369 - INFO - Relés únicos a optimizar en scenario_28: 74
# 2025-04-20 14:11:32,375 - INFO - Número de restricciones de coordinación para scenario_28: 100
# 2025-04-20 14:11:32,377 - INFO - Iniciando optimización para scenario_28 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:33,097 - INFO - Optimización scenario_28 (0.72s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:33,098 - WARNING - Fallo optimización scenario_28: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:33,098 - INFO - Valor OF final scenario_28: N/A
# 2025-04-20 14:11:33,098 - WARNING - Optimización fallida/incompleta para scenario_28. No se guardarán relay_values.
# 2025-04-20 14:11:33,098 - INFO - --- Procesando Escenario: scenario_29 (100 pares) ---
# 2025-04-20 14:11:33,099 - INFO - Relés únicos a optimizar en scenario_29: 74
# 2025-04-20 14:11:33,101 - INFO - Número de restricciones de coordinación para scenario_29: 100
# 2025-04-20 14:11:33,103 - INFO - Iniciando optimización para scenario_29 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:34,854 - INFO - Optimización scenario_29 (1.75s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:34,855 - WARNING - Fallo optimización scenario_29: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:34,856 - INFO - Valor OF final scenario_29: N/A
# 2025-04-20 14:11:34,856 - WARNING - Optimización fallida/incompleta para scenario_29. No se guardarán relay_values.
# 2025-04-20 14:11:34,856 - INFO - --- Procesando Escenario: scenario_30 (100 pares) ---
# 2025-04-20 14:11:34,856 - INFO - Relés únicos a optimizar en scenario_30: 74
# 2025-04-20 14:11:34,858 - INFO - Número de restricciones de coordinación para scenario_30: 100
# 2025-04-20 14:11:34,861 - INFO - Iniciando optimización para scenario_30 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:35,350 - INFO - Optimización scenario_30 (0.49s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:35,350 - WARNING - Fallo optimización scenario_30: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:35,350 - INFO - Valor OF final scenario_30: N/A
# 2025-04-20 14:11:35,350 - WARNING - Optimización fallida/incompleta para scenario_30. No se guardarán relay_values.
# 2025-04-20 14:11:35,350 - INFO - --- Procesando Escenario: scenario_31 (100 pares) ---
# 2025-04-20 14:11:35,351 - INFO - Relés únicos a optimizar en scenario_31: 74
# 2025-04-20 14:11:35,357 - INFO - Número de restricciones de coordinación para scenario_31: 100
# 2025-04-20 14:11:35,359 - INFO - Iniciando optimización para scenario_31 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:35,626 - INFO - Optimización scenario_31 (0.27s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:35,626 - WARNING - Fallo optimización scenario_31: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:35,627 - INFO - Valor OF final scenario_31: N/A
# 2025-04-20 14:11:35,627 - WARNING - Optimización fallida/incompleta para scenario_31. No se guardarán relay_values.
# 2025-04-20 14:11:35,627 - INFO - --- Procesando Escenario: scenario_32 (100 pares) ---
# 2025-04-20 14:11:35,628 - INFO - Relés únicos a optimizar en scenario_32: 74
# 2025-04-20 14:11:35,636 - INFO - Número de restricciones de coordinación para scenario_32: 100
# 2025-04-20 14:11:35,637 - INFO - Iniciando optimización para scenario_32 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:35,875 - INFO - Optimización scenario_32 (0.24s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:35,875 - WARNING - Fallo optimización scenario_32: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:35,875 - INFO - Valor OF final scenario_32: N/A
# 2025-04-20 14:11:35,876 - WARNING - Optimización fallida/incompleta para scenario_32. No se guardarán relay_values.
# 2025-04-20 14:11:35,876 - INFO - --- Procesando Escenario: scenario_33 (100 pares) ---
# 2025-04-20 14:11:35,876 - INFO - Relés únicos a optimizar en scenario_33: 74
# 2025-04-20 14:11:35,878 - INFO - Número de restricciones de coordinación para scenario_33: 100
# 2025-04-20 14:11:35,879 - INFO - Iniciando optimización para scenario_33 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:36,841 - INFO - Optimización scenario_33 (0.96s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:36,841 - WARNING - Fallo optimización scenario_33: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:36,842 - INFO - Valor OF final scenario_33: N/A
# 2025-04-20 14:11:36,842 - WARNING - Optimización fallida/incompleta para scenario_33. No se guardarán relay_values.
# 2025-04-20 14:11:36,842 - INFO - --- Procesando Escenario: scenario_34 (100 pares) ---
# 2025-04-20 14:11:36,843 - INFO - Relés únicos a optimizar en scenario_34: 74
# 2025-04-20 14:11:36,849 - INFO - Número de restricciones de coordinación para scenario_34: 100
# 2025-04-20 14:11:36,850 - INFO - Iniciando optimización para scenario_34 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:37,198 - INFO - Optimización scenario_34 (0.35s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:37,198 - WARNING - Fallo optimización scenario_34: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:37,198 - INFO - Valor OF final scenario_34: N/A
# 2025-04-20 14:11:37,198 - WARNING - Optimización fallida/incompleta para scenario_34. No se guardarán relay_values.
# 2025-04-20 14:11:37,199 - INFO - --- Procesando Escenario: scenario_35 (100 pares) ---
# 2025-04-20 14:11:37,200 - INFO - Relés únicos a optimizar en scenario_35: 74
# 2025-04-20 14:11:37,207 - INFO - Número de restricciones de coordinación para scenario_35: 100
# 2025-04-20 14:11:37,207 - INFO - Iniciando optimización para scenario_35 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:37,457 - INFO - Optimización scenario_35 (0.25s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:37,457 - WARNING - Fallo optimización scenario_35: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:37,458 - INFO - Valor OF final scenario_35: N/A
# 2025-04-20 14:11:37,458 - WARNING - Optimización fallida/incompleta para scenario_35. No se guardarán relay_values.
# 2025-04-20 14:11:37,458 - INFO - --- Procesando Escenario: scenario_36 (100 pares) ---
# 2025-04-20 14:11:37,459 - INFO - Relés únicos a optimizar en scenario_36: 74
# 2025-04-20 14:11:37,464 - INFO - Número de restricciones de coordinación para scenario_36: 100
# 2025-04-20 14:11:37,467 - INFO - Iniciando optimización para scenario_36 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:38,824 - INFO - Optimización scenario_36 (1.35s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:38,825 - WARNING - Fallo optimización scenario_36: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:38,825 - INFO - Valor OF final scenario_36: N/A
# 2025-04-20 14:11:38,825 - WARNING - Optimización fallida/incompleta para scenario_36. No se guardarán relay_values.
# 2025-04-20 14:11:38,825 - INFO - --- Procesando Escenario: scenario_37 (97 pares) ---
# 2025-04-20 14:11:38,826 - INFO - Relés únicos a optimizar en scenario_37: 73
# 2025-04-20 14:11:38,833 - INFO - Número de restricciones de coordinación para scenario_37: 97
# 2025-04-20 14:11:38,834 - INFO - Iniciando optimización para scenario_37 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:39,094 - INFO - Optimización scenario_37 (0.26s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:39,094 - WARNING - Fallo optimización scenario_37: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:39,095 - INFO - Valor OF final scenario_37: N/A
# 2025-04-20 14:11:39,095 - WARNING - Optimización fallida/incompleta para scenario_37. No se guardarán relay_values.
# 2025-04-20 14:11:39,095 - INFO - --- Procesando Escenario: scenario_38 (97 pares) ---
# 2025-04-20 14:11:39,096 - INFO - Relés únicos a optimizar en scenario_38: 73
# 2025-04-20 14:11:39,098 - INFO - Número de restricciones de coordinación para scenario_38: 97
# 2025-04-20 14:11:39,100 - INFO - Iniciando optimización para scenario_38 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:39,303 - INFO - Optimización scenario_38 (0.20s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:39,304 - WARNING - Fallo optimización scenario_38: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:39,304 - INFO - Valor OF final scenario_38: N/A
# 2025-04-20 14:11:39,304 - WARNING - Optimización fallida/incompleta para scenario_38. No se guardarán relay_values.
# 2025-04-20 14:11:39,305 - INFO - --- Procesando Escenario: scenario_39 (97 pares) ---
# 2025-04-20 14:11:39,305 - INFO - Relés únicos a optimizar en scenario_39: 73
# 2025-04-20 14:11:39,306 - INFO - Número de restricciones de coordinación para scenario_39: 97
# 2025-04-20 14:11:39,307 - INFO - Iniciando optimización para scenario_39 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:39,474 - INFO - Optimización scenario_39 (0.17s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:39,475 - WARNING - Fallo optimización scenario_39: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:39,475 - INFO - Valor OF final scenario_39: N/A
# 2025-04-20 14:11:39,475 - WARNING - Optimización fallida/incompleta para scenario_39. No se guardarán relay_values.
# 2025-04-20 14:11:39,475 - INFO - --- Procesando Escenario: scenario_40 (98 pares) ---
# 2025-04-20 14:11:39,477 - INFO - Relés únicos a optimizar en scenario_40: 73
# 2025-04-20 14:11:39,483 - INFO - Número de restricciones de coordinación para scenario_40: 98
# 2025-04-20 14:11:39,484 - INFO - Iniciando optimización para scenario_40 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:39,644 - INFO - Optimización scenario_40 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:39,645 - WARNING - Fallo optimización scenario_40: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:39,645 - INFO - Valor OF final scenario_40: N/A
# 2025-04-20 14:11:39,645 - WARNING - Optimización fallida/incompleta para scenario_40. No se guardarán relay_values.
# 2025-04-20 14:11:39,646 - INFO - --- Procesando Escenario: scenario_41 (97 pares) ---
# 2025-04-20 14:11:39,646 - INFO - Relés únicos a optimizar en scenario_41: 73
# 2025-04-20 14:11:39,654 - INFO - Número de restricciones de coordinación para scenario_41: 97
# 2025-04-20 14:11:39,655 - INFO - Iniciando optimización para scenario_41 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:39,986 - INFO - Optimización scenario_41 (0.33s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:39,986 - WARNING - Fallo optimización scenario_41: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:39,987 - INFO - Valor OF final scenario_41: N/A
# 2025-04-20 14:11:39,987 - WARNING - Optimización fallida/incompleta para scenario_41. No se guardarán relay_values.
# 2025-04-20 14:11:39,987 - INFO - --- Procesando Escenario: scenario_42 (97 pares) ---
# 2025-04-20 14:11:39,987 - INFO - Relés únicos a optimizar en scenario_42: 73
# 2025-04-20 14:11:39,991 - INFO - Número de restricciones de coordinación para scenario_42: 97
# 2025-04-20 14:11:39,993 - INFO - Iniciando optimización para scenario_42 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:40,158 - INFO - Optimización scenario_42 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:40,158 - WARNING - Fallo optimización scenario_42: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:40,158 - INFO - Valor OF final scenario_42: N/A
# 2025-04-20 14:11:40,159 - WARNING - Optimización fallida/incompleta para scenario_42. No se guardarán relay_values.
# 2025-04-20 14:11:40,159 - INFO - --- Procesando Escenario: scenario_43 (97 pares) ---
# 2025-04-20 14:11:40,160 - INFO - Relés únicos a optimizar en scenario_43: 73
# 2025-04-20 14:11:40,166 - INFO - Número de restricciones de coordinación para scenario_43: 97
# 2025-04-20 14:11:40,167 - INFO - Iniciando optimización para scenario_43 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:40,332 - INFO - Optimización scenario_43 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:40,332 - WARNING - Fallo optimización scenario_43: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:40,332 - INFO - Valor OF final scenario_43: N/A
# 2025-04-20 14:11:40,332 - WARNING - Optimización fallida/incompleta para scenario_43. No se guardarán relay_values.
# 2025-04-20 14:11:40,333 - INFO - --- Procesando Escenario: scenario_44 (97 pares) ---
# 2025-04-20 14:11:40,334 - INFO - Relés únicos a optimizar en scenario_44: 73
# 2025-04-20 14:11:40,340 - INFO - Número de restricciones de coordinación para scenario_44: 97
# 2025-04-20 14:11:40,340 - INFO - Iniciando optimización para scenario_44 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:40,625 - INFO - Optimización scenario_44 (0.28s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:40,625 - WARNING - Fallo optimización scenario_44: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:40,625 - INFO - Valor OF final scenario_44: N/A
# 2025-04-20 14:11:40,627 - WARNING - Optimización fallida/incompleta para scenario_44. No se guardarán relay_values.
# 2025-04-20 14:11:40,642 - INFO - --- Procesando Escenario: scenario_45 (97 pares) ---
# 2025-04-20 14:11:40,648 - INFO - Relés únicos a optimizar en scenario_45: 73
# 2025-04-20 14:11:40,680 - INFO - Número de restricciones de coordinación para scenario_45: 97
# 2025-04-20 14:11:40,687 - INFO - Iniciando optimización para scenario_45 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:40,910 - INFO - Optimización scenario_45 (0.22s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:40,911 - WARNING - Fallo optimización scenario_45: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:40,911 - INFO - Valor OF final scenario_45: N/A
# 2025-04-20 14:11:40,911 - WARNING - Optimización fallida/incompleta para scenario_45. No se guardarán relay_values.
# 2025-04-20 14:11:40,911 - INFO - --- Procesando Escenario: scenario_46 (97 pares) ---
# 2025-04-20 14:11:40,912 - INFO - Relés únicos a optimizar en scenario_46: 73
# 2025-04-20 14:11:40,919 - INFO - Número de restricciones de coordinación para scenario_46: 97
# 2025-04-20 14:11:40,919 - INFO - Iniciando optimización para scenario_46 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:41,078 - INFO - Optimización scenario_46 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:41,078 - WARNING - Fallo optimización scenario_46: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:41,078 - INFO - Valor OF final scenario_46: N/A
# 2025-04-20 14:11:41,079 - WARNING - Optimización fallida/incompleta para scenario_46. No se guardarán relay_values.
# 2025-04-20 14:11:41,079 - INFO - --- Procesando Escenario: scenario_47 (97 pares) ---
# 2025-04-20 14:11:41,080 - INFO - Relés únicos a optimizar en scenario_47: 73
# 2025-04-20 14:11:41,086 - INFO - Número de restricciones de coordinación para scenario_47: 97
# 2025-04-20 14:11:41,087 - INFO - Iniciando optimización para scenario_47 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:41,429 - INFO - Optimización scenario_47 (0.34s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:41,430 - WARNING - Fallo optimización scenario_47: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:41,430 - INFO - Valor OF final scenario_47: N/A
# 2025-04-20 14:11:41,430 - WARNING - Optimización fallida/incompleta para scenario_47. No se guardarán relay_values.
# 2025-04-20 14:11:41,430 - INFO - --- Procesando Escenario: scenario_48 (97 pares) ---
# 2025-04-20 14:11:41,431 - INFO - Relés únicos a optimizar en scenario_48: 73
# 2025-04-20 14:11:41,432 - INFO - Número de restricciones de coordinación para scenario_48: 97
# 2025-04-20 14:11:41,433 - INFO - Iniciando optimización para scenario_48 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:41,619 - INFO - Optimización scenario_48 (0.19s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:41,620 - WARNING - Fallo optimización scenario_48: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:41,620 - INFO - Valor OF final scenario_48: N/A
# 2025-04-20 14:11:41,620 - WARNING - Optimización fallida/incompleta para scenario_48. No se guardarán relay_values.
# 2025-04-20 14:11:41,620 - INFO - --- Procesando Escenario: scenario_49 (98 pares) ---
# 2025-04-20 14:11:41,621 - INFO - Relés únicos a optimizar en scenario_49: 73
# 2025-04-20 14:11:41,631 - INFO - Número de restricciones de coordinación para scenario_49: 98
# 2025-04-20 14:11:41,631 - INFO - Iniciando optimización para scenario_49 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:41,903 - INFO - Optimización scenario_49 (0.27s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:41,904 - WARNING - Fallo optimización scenario_49: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:41,904 - INFO - Valor OF final scenario_49: N/A
# 2025-04-20 14:11:41,904 - WARNING - Optimización fallida/incompleta para scenario_49. No se guardarán relay_values.
# 2025-04-20 14:11:41,905 - INFO - --- Procesando Escenario: scenario_50 (98 pares) ---
# 2025-04-20 14:11:41,906 - INFO - Relés únicos a optimizar en scenario_50: 73
# 2025-04-20 14:11:41,912 - INFO - Número de restricciones de coordinación para scenario_50: 98
# 2025-04-20 14:11:41,913 - INFO - Iniciando optimización para scenario_50 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:42,081 - INFO - Optimización scenario_50 (0.17s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:42,082 - WARNING - Fallo optimización scenario_50: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:42,082 - INFO - Valor OF final scenario_50: N/A
# 2025-04-20 14:11:42,082 - WARNING - Optimización fallida/incompleta para scenario_50. No se guardarán relay_values.
# 2025-04-20 14:11:42,083 - INFO - --- Procesando Escenario: scenario_51 (98 pares) ---
# 2025-04-20 14:11:42,083 - INFO - Relés únicos a optimizar en scenario_51: 73
# 2025-04-20 14:11:42,084 - INFO - Número de restricciones de coordinación para scenario_51: 98
# 2025-04-20 14:11:42,085 - INFO - Iniciando optimización para scenario_51 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:42,245 - INFO - Optimización scenario_51 (0.16s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:42,246 - WARNING - Fallo optimización scenario_51: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:42,246 - INFO - Valor OF final scenario_51: N/A
# 2025-04-20 14:11:42,246 - WARNING - Optimización fallida/incompleta para scenario_51. No se guardarán relay_values.
# 2025-04-20 14:11:42,246 - INFO - --- Procesando Escenario: scenario_52 (98 pares) ---
# 2025-04-20 14:11:42,246 - INFO - Relés únicos a optimizar en scenario_52: 73
# 2025-04-20 14:11:42,254 - INFO - Número de restricciones de coordinación para scenario_52: 98
# 2025-04-20 14:11:42,254 - INFO - Iniciando optimización para scenario_52 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:42,518 - INFO - Optimización scenario_52 (0.26s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:42,518 - WARNING - Fallo optimización scenario_52: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:42,518 - INFO - Valor OF final scenario_52: N/A
# 2025-04-20 14:11:42,519 - WARNING - Optimización fallida/incompleta para scenario_52. No se guardarán relay_values.
# 2025-04-20 14:11:42,520 - INFO - --- Procesando Escenario: scenario_53 (100 pares) ---
# 2025-04-20 14:11:42,522 - INFO - Relés únicos a optimizar en scenario_53: 74
# 2025-04-20 14:11:42,544 - INFO - Número de restricciones de coordinación para scenario_53: 100
# 2025-04-20 14:11:42,554 - INFO - Iniciando optimización para scenario_53 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:43,069 - INFO - Optimización scenario_53 (0.51s). Estado: 4 (Inequality constraints incompatible)
# 2025-04-20 14:11:43,070 - WARNING - Fallo optimización scenario_53: Inequality constraints incompatible (Status=4)
# 2025-04-20 14:11:43,070 - INFO - Valor OF final scenario_53: N/A
# 2025-04-20 14:11:43,070 - WARNING - Optimización fallida/incompleta para scenario_53. No se guardarán relay_values.
# 2025-04-20 14:11:43,071 - INFO - --- Procesando Escenario: scenario_54 (100 pares) ---
# 2025-04-20 14:11:43,071 - INFO - Relés únicos a optimizar en scenario_54: 74
# 2025-04-20 14:11:43,075 - INFO - Número de restricciones de coordinación para scenario_54: 100
# 2025-04-20 14:11:43,075 - INFO - Iniciando optimización para scenario_54 con método SLSQP (tolerancias relajadas)...
# 2025-04-20 14:11:43,326 - INFO - Optimización scenario_54 (0.25s). Estado: 8 (Positive directional derivative for linesearch)
# 2025-04-20 14:11:43,326 - WARNING - Fallo optimización scenario_54: Positive directional derivative for linesearch (Status=8)
# 2025-04-20 14:11:43,327 - INFO - Valor OF final scenario_54: N/A
# 2025-04-20 14:11:43,327 - WARNING - Optimización fallida/incompleta para scenario_54. No se guardarán relay_values.
# 2025-04-20 14:11:43,327 - INFO - --- Procesando Escenario: scenario_55 (100 pares) ---
# 2025-04-20 14:11:43,329 - INFO - Relés únicos a optimizar en scenario_55: 74
# 2025-04-20 14:11:43,335 - INFO - Número de restricciones de coordinación para scenario_55: 100
# 2025-04-20 14:11:43,335 - INFO - Iniciando optimización para scenario_55 con método SLSQP (tolerancias relajadas)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 266
#     264 # --- Punto de Entrada ---
#     265 if __name__ == "__main__":
# --> 266    run_and_unify(input_json_path=INPUT_JSON,
#     267                  output_json_path=OUTPUT_JSON,
#     268                  cti_value=CTI)
#
# Cell In[22], line 168, in run_and_unify(input_json_path, output_json_path, cti_value)
#     165 if len(x0) != num_vars: raise ValueError(f"Tamaño x0 ({len(x0)}) != num_vars ({num_vars}) en {scen}")
#     167 # Llamada a minimize con SLSQP y nuevas opciones
# --> 168 res = minimize(
#     169     objective_scenario,
#     170     x0,
#     171     args=obj_args,
#     172     method=optimization_method,
#     173     bounds=bnds, # Lista de tuplas para SLSQP
#     174     constraints=cons, # Lista de diccionarios para SLSQP
#     175     options=options
#     176 )
#     178 end_time = datetime.datetime.now(); duration = (end_time - start_time).total_seconds()
#     179 logger.info(f"Optimización {scen} ({duration:.2f}s). Estado: {res.status} ({res.message})")
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/optimize/_minimize.py:722, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
# --> 722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#     724 elif meth == 'trust-constr':
#     725     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     726                                        bounds, constraints,
#     727                                        callback=callback, **options)
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/optimize/_slsqp_py.py:442, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     440 if mode == -1:  # gradient evaluation required
#     441     g = append(wrapped_grad(x), 0.0)
# --> 442     a = _eval_con_normals(x, cons, la, n, m, meq, mieq)
#     444 if majiter > majiter_prev:
#     445     # call callback if major iteration has incremented
#     446     if callback is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/optimize/_slsqp_py.py:501, in _eval_con_normals(x, cons, la, n, m, meq, mieq)
#     498     a_eq = zeros((meq, n))
#     500 if cons['ineq']:
# --> 501     a_ieq = vstack([con['jac'](x, *con['args'])
#     502                     for con in cons['ineq']])
#     503 else:  # no inequality constraint
#     504     a_ieq = zeros((mieq, n))
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/optimize/_slsqp_py.py:501, in <listcomp>(.0)
#     498     a_eq = zeros((meq, n))
#     500 if cons['ineq']:
# --> 501     a_ieq = vstack([con['jac'](x, *con['args'])
#     502                     for con in cons['ineq']])
#     503 else:  # no inequality constraint
#     504     a_ieq = zeros((mieq, n))
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/optimize/_slsqp_py.py:310, in _minimize_slsqp.<locals>.cjac_factory.<locals>.cjac(x, *args)
#     306     return approx_derivative(fun, x, method=jac, args=args,
#     307                              rel_step=finite_diff_rel_step,
#     308                              bounds=new_bounds)
#     309 else:
# --> 310     return approx_derivative(fun, x, method='2-point',
#     311                              abs_step=epsilon, args=args,
#     312                              bounds=new_bounds)
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:467, in approx_derivative.<locals>.fun_wrapped(x)
#     464 def fun_wrapped(x):
#     465     # send user function same fp type as x0. (but only if cs is not being
#     466     # used
# --> 467     if xp.isdtype(x.dtype, "real floating"):
#     468         x = xp.astype(x, x0.dtype)
#     470     f = np.atleast_1d(fun(x, *args, **kwargs))
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/_lib/array_api_compat/array_api_compat/_internal.py:27, in get_xp.<locals>.inner.<locals>.wrapped_f(*args, **kwargs)
#      25 @wraps(f)
#      26 def wrapped_f(*args, **kwargs):
# ---> 27     return f(*args, xp=xp, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/_lib/array_api_compat/array_api_compat/common/_aliases.py:510, in isdtype(dtype, kind, xp, _tuple)
#     508     return xp.issubdtype(dtype, xp.integer)
#     509 elif kind == 'real floating':
# --> 510     return xp.issubdtype(dtype, xp.floating)
#     511 elif kind == 'complex floating':
#     512     return xp.issubdtype(dtype, xp.complexfloating)
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/numerictypes.py:420, in issubdtype(arg1, arg2)
#     417 if not issubclass_(arg2, generic):
#     418     arg2 = dtype(arg2).type
# --> 420 return issubclass(arg1, arg2)
#
# KeyboardInterrupt:
